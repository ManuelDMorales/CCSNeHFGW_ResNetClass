# %% [markdown]
# <font size="5.5"><u><i>Process Numerical Waveforms</i></u></font>

# %% [markdown]
# <font size="4">Script to apply all processes for building the strain dataset of Numerical Waveforms.</font>
# <br/>
# <font size="4">Author: Manuel David Morales</font>

# %% [markdown]
# ## 1. Library imports

# %%
# Data analysis
import numpy as np 
import pandas as pd
import math

# Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt

# Files/folders management
import os, glob, sys, re

# To read csv files
import csv

# Scientific computing
from scipy import signal

# Garbage collector
import gc

# Object serialization
import pickle

# Toolbox functions
from Toolbox import PSD, SNR, SNR_PyCBC, whitening_PyCBC, filt_bandpass_PyCBC, WaveletTF_transform

# %% [markdown]
# ## 2. Make Injections

# %% [markdown]
# ### 2.1. Input parameters

# %%
# Select waveform to inject
# ------------------------------------------------------------------------------
wf_model = "Cerda-Duran_2013"    # Options: Andresen_2019 - class 1
                                 #          Morozova_2018 - class 2
                                 #          Cerda-Duran_2013 - class 3
# ------------------------------------------------------------------------------

# Select interferometer for noise data
# ------------------------------------------------------------
detector = "L1"   # Options: "L1", "H1", "V1"
# ------------------------------------------------------------

# Time between injections (in seconds)
# ------------------------------------------------------------
dt_inj = 8   # Options: 8, 12, 16, 32, 64
# ------------------------------------------------------------

# Jitter_lim: This value defines a fluctuation range, in which each
# injection will be located on a random sample in the interval
# [inj_time - jitter_lim, inj_time + jitter_lim] (in seconds)
# ------------------------------------------------------------
jitter_lim = 0.01   # Options: 0.3, 0.1, 0.0, 1.2, etc.
# ------------------------------------------------------------

# Time segment for SNR calculation around injection (in seconds)
# ----------------------------------------------------------------
t_segment = 4   #  [ t_inj-t_segment/2 , t_inj+t_segment/2 ] 
# ----------------------------------------------------------------

# ------> Input parameters for brief exploration and debugging

# Work on a reduced noise segment?
# ----------------------------------------------------------------
reduce_segment = 0   #  1: yes | 0: no
# ----------------------------------------------------------------

# Length of the reduced noise segment (in seconds)
# ----------------------------------------------------------------
reduced_time_n = 80.0                      
# ----------------------------------------------------------------

# %% [markdown]
# ### 2.2. Read files

# %% [markdown]
# #### 2.2.1 Noise data

# %%
# ------> Specify folder locations

rawdata_dir = '/home/manuel/Research Projects/GW Data analysis/GitHub/CCSNeHFGW_ResNetClass/Codes/'

# ------> Initialize lists

time_noise = []
strain_noise = []
F_noi = []

# ------> Scan noise files

os.chdir(rawdata_dir)

for file in glob.glob("strain_noise_" + detector + "*"):
    F_noi.append(file)

# %%
# ------> Load noise data 

result = re.search( detector + "_", F_noi[0])
ind_ini_n = result.span()[1]
result = re.search( ".txt", F_noi[0])
ind_end_n = result.span()[0]

print("Available noise segments (in GPS start time)")
for j in range(len(F_noi)):
    print("GPS =", F_noi[j][ind_ini_n:ind_end_n], "  |  Input option :", j)
print("")

nfile_i = input("======> Enter your option:")
nfile_i = int(nfile_i)
print("")

print("***** READING FILE", F_noi[nfile_i], " *****")

with open(F_noi[nfile_i]) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Data columns: {", ".join(row)}')
            line_count += 1
        else:
            time_noise.append(row[0])
            strain_noise.append(row[1])
            #print(f'\t{row[0]} works in the {row[1]}.')
            line_count += 1
    print(f'Processed {line_count} lines')
# Out:
# Available noise segments (in GPS start time)
# GPS = 1256783872   |  Input option : 0
# GPS = 1257050112   |  Input option : 1
# ======> Enter your option: 0
# ***** READING FILE strain_noise_L1_1256783872.txt  *****
# Data columns: time, strain
# Processed 16777217 lines

# %%
# ------> Convert lists to numpy arrays, clear memory from lists

time_n = np.array(time_noise, dtype='float64')
del(time_noise)
gc.collect()

strain_n = np.array(strain_noise, dtype='float64')
del(strain_noise)
gc.collect()
# Out:
# 0

# %% [markdown]
# #### 2.2.2 Waveform data

# %%
# ------> Specify folder locations

wfdata_dir = '/home/manuel/Research Projects/GW Data analysis/GitHub/CCSNeHFGW_ResNetClass/Waveforms_mod/Num'

# ------> Initialize lists

time_waveform = []
strain_waveform = []
F_wav = []

# ------> Scan waveform files

os.chdir(wfdata_dir)

for file in glob.glob(wf_model + "*"):
    F_wav.append(file)

# %%
print("Available waveforms")
for j in range(len(F_wav)):
    print(F_wav[j], "  |  Input option :", j)
print("")

wfile_i = input("======> Enter your option:")
wfile_i = int(wfile_i)
print("")

print("***** READING FILE", F_wav[wfile_i], " *****")
with open(F_wav[wfile_i]) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Data columns: {", ".join(row)}')
            line_count += 1
        else:
            time_waveform.append(row[0])
            strain_waveform.append(row[1])
            #print(f'\t{row[0]} works in the {row[1]}.')
            line_count += 1
    print(f'Processed {line_count} lines')

print("")
# Out:
# Available waveforms
# Cerda-Duran_2013_fiducial_h+_D_1Kpc_dur_1.599853515625s_HFFslope_956_class_3.txt   |  Input option : 0
# ======> Enter your option: 0
# ***** READING FILE Cerda-Duran_2013_fiducial_h+_D_1Kpc_dur_1.599853515625s_HFFslope_956_class_3.txt  *****
# Data columns: time, strain
# Processed 4999 lines

# %%
# ------> Convert lists to numpy arrays, clear memory from lists

time_wf = np.array(time_waveform, dtype='float64')
del(time_waveform)
gc.collect()

strain_wf = np.array(strain_waveform, dtype='float64')
del(strain_waveform)
gc.collect()
# Out:
# 0

# %% [markdown]
# ### 2.3. Injections preparation

# %%
# Compute sampling time

ts = time_n[1] - time_n[0]

# -------> JUST FOR DEBUGGING THE IMPLEMENTATION
#          Select a portion of the noise strain data

if reduce_segment:
    
    reduced_length = int(reduced_time_n/ts)     # Reduced noise arrays' length (in sample units)
    
    time_n = np.delete(time_n,np.arange(reduced_length, len(time_n), 1, dtype=int))
    strain_n = np.delete(strain_n,np.arange(reduced_length, len(strain_n), 1, dtype=int))
    
    #print("time_n vector:", time_n)
    print("**** length of time_n (in seconds):", len(time_n)*ts)
    print("**** length of time_n (in sample units):", len(time_n))
    print("**** length of strain_n (in sample units):", len(strain_n))

# %%
# ------> Backup original strain arrays
strain_n_new = np.copy(strain_n) # ---> Deep copy in numpy, to unbind arrays

# ------> Print useful input information

# Sampling frequency
fs =1/ts
print("Sampling frequency (in Hz): ", fs)

# Index of the strain noise sample (point) in which the first injection will be performed
N_lapse = int(dt_inj/(1./fs))
print("First noise sample to be injected with a waveform (without jitter): ", N_lapse)
print("Its correspondent strain value:", strain_n_new[N_lapse])

# Number of injections to be performed in the strain data
N_inj = int(len(strain_n_new) / N_lapse) - 1 
# Remark: -1 value in N_inj is just to avoid incomplete injection at the right edge.  
print("Number of injections to be performed: ", N_inj)
# Out:
# Sampling frequency (in Hz):  4096.0
# First noise sample to be injected with a waveform (without jitter):  32768
# Its correspondent strain value: 2.980782469955117e-19
# Number of injections to be performed:  511

# %%
# ------> Compute waveform duration

wf_duration = time_wf[-1] - time_wf[0]
print("Waveform duration (in seconds)", wf_duration)
print("")
# Out:
# Waveform duration (in seconds) 1.219970703125

# %% [markdown]
# ### 2.4. Injections application

# %%
doplots_snr = 0 # Do plots in SNR calculation (checks)

# ------> Create array to locate injections by indexes

locate_inj = np.arange(1,N_inj+1)
locate_inj = N_lapse*locate_inj
#print(locate_inj[-1] + N_lapse)
#print(len(strain_n_new))

# ------> Define length of local noise segment for SNR calculation

epsilon = int(int(t_segment/ts)*0.5)
#print("Epsilon = ", epsilon)

# ------> Initialize list for log file

log_data = []

# ------> Make injections

for j in range(N_inj): # Apply all injections
#for j in range(10): # Apply only a few injections
    
    print("Injection No.", j)
    print("----------------------")
    
    # ------> Injection location without jitter
    
    ind_noise = locate_inj[j] # Locate first point of the injection
    # print("Injection first point in the strain noise data (without jitter):", ind_noise)
    
    time_inj = (1./fs)*ind_noise
    print("Time injection, without jitter (in seconds):", time_inj)
    
    # ------> Jitter variable procedure
    
    # Define the jitter range in terms of sample units
    njitter_range_min = ind_noise + int(-jitter_lim/(1./fs))
    njitter_range_max = ind_noise + int(jitter_lim/(1./fs))
    njitter_range = np.arange(njitter_range_min, njitter_range_max + 1, 1, dtype=int)

    # Compute actual location of the injection in sample units
    njitter = np.random.choice(njitter_range, 1)[0]
    
    # Some checks
    #print("Jitter variable range (in sample units):", njitter_range)
    #print("Modified injection location (in sample units):", njitter)
    current_jitter = (njitter-ind_noise)*(1/fs)
    print("Current jitter (in seconds):", current_jitter)
    
    time_inj_jit = njitter*(1/fs)
    print("Time injection, with jitter (in seconds):", time_inj_jit)

    # ------> Update index injection locations
    
    locate_inj[j] = njitter 
    
    # SECOND LOOP, k index: Waveform's sample count variable
    # --------------------------------------------------------
    
    for k in range(len(strain_wf)): # Injection along waveform's ALL points
    #for k in range(3): # Injection along waveform's first three points
    #for k in reversed(range(len(strain_wf)-3,len(strain_wf),1)): # Injection along waveform's last three points
        
        #print("")
        #print("+++++ Point", k, " of the waveform")
        
        strain_waveform = strain_wf[k] 
        #print("------> strain waveform", strain_waveform)
        
        strain_noise = strain_n_new[locate_inj[j]+k]
        #print("------> strain BEFORE injection", strain_noise)
    
        # PERFORM THE INJECTION (k point in the waveform, locate_inj[j] + k point in the noise)
        strain_with_inj = strain_noise + strain_waveform
        strain_n_new[locate_inj[j]+k] = strain_with_inj
    
        #print("------> strain AFTER injection", strain_n_new[ind_noise+k])
        #print("------> strain AFTER injection in copy", strain_n[ind_noise+k])
    
    print("")
    print("+++++ SNR calculation +++++")
    
    # ------> Define time segment for SNR calculation around the injection
    
    Llim_local_noise = ind_noise - epsilon
    Rlim_local_noise = ind_noise + len(strain_wf) + epsilon
    
    print("Left limit local noise = ", Llim_local_noise)
    print("Right limit local noise = ", Rlim_local_noise)
    
    print("Strain noise length (in sample units):", len(strain_n_new))
    
    # Define strain noise segment
    strain_segment = strain_n_new[Llim_local_noise:Rlim_local_noise+1]
    
    print("Strain noise segment length (in sample units):", len(strain_segment))
    
    # ------> Compute PSD
    
    # Size of Welch's segments
    nperseg = int(4*fs)
    
    # Double-sided power spectral density of raw strain data
    fpsd, psd = PSD(strain_segment,fs,nperseg,2)
    
    # Sort arrays, increasing frequencies
    ind = np.argsort(fpsd)
    fpsd = np.sort(fpsd)
    psd = psd[ind]
    
    # ------> Compute SNR values (with PyCBC)
    
    SNR_value = SNR_PyCBC(strain_wf, strain_segment, fs, doplots_snr)
    
    print("Injection SNR value (PyCBC): ", SNR_value)
    
    if np.isnan(SNR_value):
            
        print("!!!!!!!!!!!!!!!!! STOPPING INJECTION PROCEDURE, SNR VALUE IS \"NAN\" !!!!!!!!!!!!!!!!! ")
        break
    
    # ------> Save information in log_data list
    # Injection time, jitter, SNR value, waveform duration
    log_data.append([time_inj_jit, current_jitter, SNR_value, wf_duration])
    
    print("****************************************************************")
    print("")
# Out:
# Injection No. 0
# ----------------------
# Time injection, without jitter (in seconds): 8.0
# Current jitter (in seconds): 0.00341796875
# Time injection, with jitter (in seconds): 8.00341796875
#
# +++++ SNR calculation +++++
# Left limit local noise =  24576
# Right limit local noise =  45958
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.59198275914237
# ****************************************************************
#
# Injection No. 1
# ----------------------
# Time injection, without jitter (in seconds): 16.0
# Current jitter (in seconds): 0.009521484375
# Time injection, with jitter (in seconds): 16.009521484375
#
# +++++ SNR calculation +++++
# Left limit local noise =  57344
# Right limit local noise =  78726
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.55253231458876
# ****************************************************************
#
# Injection No. 2
# ----------------------
# Time injection, without jitter (in seconds): 24.0
# Current jitter (in seconds): 0.000244140625
# Time injection, with jitter (in seconds): 24.000244140625
#
# +++++ SNR calculation +++++
# Left limit local noise =  90112
# Right limit local noise =  111494
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.360319973659
# ****************************************************************
#
# Injection No. 3
# ----------------------
# Time injection, without jitter (in seconds): 32.0
# Current jitter (in seconds): 0.002685546875
# Time injection, with jitter (in seconds): 32.002685546875
#
# +++++ SNR calculation +++++
# Left limit local noise =  122880
# Right limit local noise =  144262
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.82735261877362
# ****************************************************************
#
# Injection No. 4
# ----------------------
# Time injection, without jitter (in seconds): 40.0
# Current jitter (in seconds): -0.006103515625
# Time injection, with jitter (in seconds): 39.993896484375
#
# +++++ SNR calculation +++++
# Left limit local noise =  155648
# Right limit local noise =  177030
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.34326813640489
# ****************************************************************
#
# Injection No. 5
# ----------------------
# Time injection, without jitter (in seconds): 48.0
# Current jitter (in seconds): 0.005126953125
# Time injection, with jitter (in seconds): 48.005126953125
#
# +++++ SNR calculation +++++
# Left limit local noise =  188416
# Right limit local noise =  209798
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.56199048940366
# ****************************************************************
#
# Injection No. 6
# ----------------------
# Time injection, without jitter (in seconds): 56.0
# Current jitter (in seconds): -0.002685546875
# Time injection, with jitter (in seconds): 55.997314453125
#
# +++++ SNR calculation +++++
# Left limit local noise =  221184
# Right limit local noise =  242566
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.24965193524923
# ****************************************************************
#
# Injection No. 7
# ----------------------
# Time injection, without jitter (in seconds): 64.0
# Current jitter (in seconds): 0.00244140625
# Time injection, with jitter (in seconds): 64.00244140625
#
# +++++ SNR calculation +++++
# Left limit local noise =  253952
# Right limit local noise =  275334
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.3299665673607
# ****************************************************************
#
# Injection No. 8
# ----------------------
# Time injection, without jitter (in seconds): 72.0
# Current jitter (in seconds): 0.0087890625
# Time injection, with jitter (in seconds): 72.0087890625
#
# +++++ SNR calculation +++++
# Left limit local noise =  286720
# Right limit local noise =  308102
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.69120190377835
# ****************************************************************
#
# Injection No. 9
# ----------------------
# Time injection, without jitter (in seconds): 80.0
# Current jitter (in seconds): -0.0009765625
# Time injection, with jitter (in seconds): 79.9990234375
#
# +++++ SNR calculation +++++
# Left limit local noise =  319488
# Right limit local noise =  340870
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.7555940071533
# ****************************************************************
#
# Injection No. 10
# ----------------------
# Time injection, without jitter (in seconds): 88.0
# Current jitter (in seconds): -0.00390625
# Time injection, with jitter (in seconds): 87.99609375
#
# +++++ SNR calculation +++++
# Left limit local noise =  352256
# Right limit local noise =  373638
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.34239710706542
# ****************************************************************
#
# Injection No. 11
# ----------------------
# Time injection, without jitter (in seconds): 96.0
# Current jitter (in seconds): -0.006103515625
# Time injection, with jitter (in seconds): 95.993896484375
#
# +++++ SNR calculation +++++
# Left limit local noise =  385024
# Right limit local noise =  406406
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  84.18651242533277
# ****************************************************************
#
# Injection No. 12
# ----------------------
# Time injection, without jitter (in seconds): 104.0
# Current jitter (in seconds): 0.001220703125
# Time injection, with jitter (in seconds): 104.001220703125
#
# +++++ SNR calculation +++++
# Left limit local noise =  417792
# Right limit local noise =  439174
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.78056218840082
# ****************************************************************
#
# Injection No. 13
# ----------------------
# Time injection, without jitter (in seconds): 112.0
# Current jitter (in seconds): -0.005615234375
# Time injection, with jitter (in seconds): 111.994384765625
#
# +++++ SNR calculation +++++
# Left limit local noise =  450560
# Right limit local noise =  471942
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.87953369474559
# ****************************************************************
#
# Injection No. 14
# ----------------------
# Time injection, without jitter (in seconds): 120.0
# Current jitter (in seconds): 0.008056640625
# Time injection, with jitter (in seconds): 120.008056640625
#
# +++++ SNR calculation +++++
# Left limit local noise =  483328
# Right limit local noise =  504710
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.54589031541099
# ****************************************************************
#
# Injection No. 15
# ----------------------
# Time injection, without jitter (in seconds): 128.0
# Current jitter (in seconds): -0.002685546875
# Time injection, with jitter (in seconds): 127.997314453125
#
# +++++ SNR calculation +++++
# Left limit local noise =  516096
# Right limit local noise =  537478
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.47769155831936
# ****************************************************************
#
# Injection No. 16
# ----------------------
# Time injection, without jitter (in seconds): 136.0
# Current jitter (in seconds): 0.007080078125
# Time injection, with jitter (in seconds): 136.007080078125
#
# +++++ SNR calculation +++++
# Left limit local noise =  548864
# Right limit local noise =  570246
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.86177055424413
# ****************************************************************
#
# Injection No. 17
# ----------------------
# Time injection, without jitter (in seconds): 144.0
# Current jitter (in seconds): 0.0029296875
# Time injection, with jitter (in seconds): 144.0029296875
#
# +++++ SNR calculation +++++
# Left limit local noise =  581632
# Right limit local noise =  603014
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.60345976703893
# ****************************************************************
#
# Injection No. 18
# ----------------------
# Time injection, without jitter (in seconds): 152.0
# Current jitter (in seconds): -0.003662109375
# Time injection, with jitter (in seconds): 151.996337890625
#
# +++++ SNR calculation +++++
# Left limit local noise =  614400
# Right limit local noise =  635782
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  84.13968678755607
# ****************************************************************
#
# Injection No. 19
# ----------------------
# Time injection, without jitter (in seconds): 160.0
# Current jitter (in seconds): -0.007080078125
# Time injection, with jitter (in seconds): 159.992919921875
#
# +++++ SNR calculation +++++
# Left limit local noise =  647168
# Right limit local noise =  668550
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.4822983186662
# ****************************************************************
#
# Injection No. 20
# ----------------------
# Time injection, without jitter (in seconds): 168.0
# Current jitter (in seconds): -0.008544921875
# Time injection, with jitter (in seconds): 167.991455078125
#
# +++++ SNR calculation +++++
# Left limit local noise =  679936
# Right limit local noise =  701318
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.82438287558792
# ****************************************************************
#
# Injection No. 21
# ----------------------
# Time injection, without jitter (in seconds): 176.0
# Current jitter (in seconds): 0.004150390625
# Time injection, with jitter (in seconds): 176.004150390625
#
# +++++ SNR calculation +++++
# Left limit local noise =  712704
# Right limit local noise =  734086
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.21631209063497
# ****************************************************************
#
# Injection No. 22
# ----------------------
# Time injection, without jitter (in seconds): 184.0
# Current jitter (in seconds): 0.007080078125
# Time injection, with jitter (in seconds): 184.007080078125
#
# +++++ SNR calculation +++++
# Left limit local noise =  745472
# Right limit local noise =  766854
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.5183175772041
# ****************************************************************
#
# Injection No. 23
# ----------------------
# Time injection, without jitter (in seconds): 192.0
# Current jitter (in seconds): 0.00244140625
# Time injection, with jitter (in seconds): 192.00244140625
#
# +++++ SNR calculation +++++
# Left limit local noise =  778240
# Right limit local noise =  799622
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  84.6338923581969
# ****************************************************************
#
# Injection No. 24
# ----------------------
# Time injection, without jitter (in seconds): 200.0
# Current jitter (in seconds): 0.002197265625
# Time injection, with jitter (in seconds): 200.002197265625
#
# +++++ SNR calculation +++++
# Left limit local noise =  811008
# Right limit local noise =  832390
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.87125861041815
# ****************************************************************
#
# Injection No. 25
# ----------------------
# Time injection, without jitter (in seconds): 208.0
# Current jitter (in seconds): -0.00634765625
# Time injection, with jitter (in seconds): 207.99365234375
#
# +++++ SNR calculation +++++
# Left limit local noise =  843776
# Right limit local noise =  865158
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.94002137880435
# ****************************************************************
#
# Injection No. 26
# ----------------------
# Time injection, without jitter (in seconds): 216.0
# Current jitter (in seconds): 0.001708984375
# Time injection, with jitter (in seconds): 216.001708984375
#
# +++++ SNR calculation +++++
# Left limit local noise =  876544
# Right limit local noise =  897926
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.90869403495027
# ****************************************************************
#
# Injection No. 27
# ----------------------
# Time injection, without jitter (in seconds): 224.0
# Current jitter (in seconds): 0.00341796875
# Time injection, with jitter (in seconds): 224.00341796875
#
# +++++ SNR calculation +++++
# Left limit local noise =  909312
# Right limit local noise =  930694
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.78033695593727
# ****************************************************************
#
# Injection No. 28
# ----------------------
# Time injection, without jitter (in seconds): 232.0
# Current jitter (in seconds): -0.00537109375
# Time injection, with jitter (in seconds): 231.99462890625
#
# +++++ SNR calculation +++++
# Left limit local noise =  942080
# Right limit local noise =  963462
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  79.79420479190902
# ****************************************************************
#
# Injection No. 29
# ----------------------
# Time injection, without jitter (in seconds): 240.0
# Current jitter (in seconds): -0.001953125
# Time injection, with jitter (in seconds): 239.998046875
#
# +++++ SNR calculation +++++
# Left limit local noise =  974848
# Right limit local noise =  996230
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.94947840986026
# ****************************************************************
#
# Injection No. 30
# ----------------------
# Time injection, without jitter (in seconds): 248.0
# Current jitter (in seconds): -0.001220703125
# Time injection, with jitter (in seconds): 247.998779296875
#
# +++++ SNR calculation +++++
# Left limit local noise =  1007616
# Right limit local noise =  1028998
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.58427961915689
# ****************************************************************
#
# Injection No. 31
# ----------------------
# Time injection, without jitter (in seconds): 256.0
# Current jitter (in seconds): -0.0068359375
# Time injection, with jitter (in seconds): 255.9931640625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1040384
# Right limit local noise =  1061766
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.81808261205295
# ****************************************************************
#
# Injection No. 32
# ----------------------
# Time injection, without jitter (in seconds): 264.0
# Current jitter (in seconds): 0.009033203125
# Time injection, with jitter (in seconds): 264.009033203125
#
# +++++ SNR calculation +++++
# Left limit local noise =  1073152
# Right limit local noise =  1094534
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.52933582292412
# ****************************************************************
#
# Injection No. 33
# ----------------------
# Time injection, without jitter (in seconds): 272.0
# Current jitter (in seconds): -0.00537109375
# Time injection, with jitter (in seconds): 271.99462890625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1105920
# Right limit local noise =  1127302
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  79.99887081897879
# ****************************************************************
#
# Injection No. 34
# ----------------------
# Time injection, without jitter (in seconds): 280.0
# Current jitter (in seconds): -0.0068359375
# Time injection, with jitter (in seconds): 279.9931640625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1138688
# Right limit local noise =  1160070
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.42443382360429
# ****************************************************************
#
# Injection No. 35
# ----------------------
# Time injection, without jitter (in seconds): 288.0
# Current jitter (in seconds): -0.000732421875
# Time injection, with jitter (in seconds): 287.999267578125
#
# +++++ SNR calculation +++++
# Left limit local noise =  1171456
# Right limit local noise =  1192838
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.50653629205435
# ****************************************************************
#
# Injection No. 36
# ----------------------
# Time injection, without jitter (in seconds): 296.0
# Current jitter (in seconds): -0.00927734375
# Time injection, with jitter (in seconds): 295.99072265625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1204224
# Right limit local noise =  1225606
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.96769706025339
# ****************************************************************
#
# Injection No. 37
# ----------------------
# Time injection, without jitter (in seconds): 304.0
# Current jitter (in seconds): -0.00146484375
# Time injection, with jitter (in seconds): 303.99853515625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1236992
# Right limit local noise =  1258374
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.14623311682809
# ****************************************************************
#
# Injection No. 38
# ----------------------
# Time injection, without jitter (in seconds): 312.0
# Current jitter (in seconds): 0.00146484375
# Time injection, with jitter (in seconds): 312.00146484375
#
# +++++ SNR calculation +++++
# Left limit local noise =  1269760
# Right limit local noise =  1291142
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.06711018278313
# ****************************************************************
#
# Injection No. 39
# ----------------------
# Time injection, without jitter (in seconds): 320.0
# Current jitter (in seconds): -0.009765625
# Time injection, with jitter (in seconds): 319.990234375
#
# +++++ SNR calculation +++++
# Left limit local noise =  1302528
# Right limit local noise =  1323910
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.77183745129368
# ****************************************************************
#
# Injection No. 40
# ----------------------
# Time injection, without jitter (in seconds): 328.0
# Current jitter (in seconds): -0.001708984375
# Time injection, with jitter (in seconds): 327.998291015625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1335296
# Right limit local noise =  1356678
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.65498937477392
# ****************************************************************
#
# Injection No. 41
# ----------------------
# Time injection, without jitter (in seconds): 336.0
# Current jitter (in seconds): 0.005126953125
# Time injection, with jitter (in seconds): 336.005126953125
#
# +++++ SNR calculation +++++
# Left limit local noise =  1368064
# Right limit local noise =  1389446
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.95964693351358
# ****************************************************************
#
# Injection No. 42
# ----------------------
# Time injection, without jitter (in seconds): 344.0
# Current jitter (in seconds): -0.007568359375
# Time injection, with jitter (in seconds): 343.992431640625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1400832
# Right limit local noise =  1422214
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.10520582777635
# ****************************************************************
#
# Injection No. 43
# ----------------------
# Time injection, without jitter (in seconds): 352.0
# Current jitter (in seconds): -0.0009765625
# Time injection, with jitter (in seconds): 351.9990234375
#
# +++++ SNR calculation +++++
# Left limit local noise =  1433600
# Right limit local noise =  1454982
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.64031597581638
# ****************************************************************
#
# Injection No. 44
# ----------------------
# Time injection, without jitter (in seconds): 360.0
# Current jitter (in seconds): 0.005126953125
# Time injection, with jitter (in seconds): 360.005126953125
#
# +++++ SNR calculation +++++
# Left limit local noise =  1466368
# Right limit local noise =  1487750
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.12036783089697
# ****************************************************************
#
# Injection No. 45
# ----------------------
# Time injection, without jitter (in seconds): 368.0
# Current jitter (in seconds): -0.0048828125
# Time injection, with jitter (in seconds): 367.9951171875
#
# +++++ SNR calculation +++++
# Left limit local noise =  1499136
# Right limit local noise =  1520518
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.1976253384002
# ****************************************************************
#
# Injection No. 46
# ----------------------
# Time injection, without jitter (in seconds): 376.0
# Current jitter (in seconds): 0.006591796875
# Time injection, with jitter (in seconds): 376.006591796875
#
# +++++ SNR calculation +++++
# Left limit local noise =  1531904
# Right limit local noise =  1553286
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  83.30980310257416
# ****************************************************************
#
# Injection No. 47
# ----------------------
# Time injection, without jitter (in seconds): 384.0
# Current jitter (in seconds): -0.009521484375
# Time injection, with jitter (in seconds): 383.990478515625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1564672
# Right limit local noise =  1586054
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.040746925304
# ****************************************************************
#
# Injection No. 48
# ----------------------
# Time injection, without jitter (in seconds): 392.0
# Current jitter (in seconds): 0.0078125
# Time injection, with jitter (in seconds): 392.0078125
#
# +++++ SNR calculation +++++
# Left limit local noise =  1597440
# Right limit local noise =  1618822
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.39315157252996
# ****************************************************************
#
# Injection No. 49
# ----------------------
# Time injection, without jitter (in seconds): 400.0
# Current jitter (in seconds): 0.006591796875
# Time injection, with jitter (in seconds): 400.006591796875
#
# +++++ SNR calculation +++++
# Left limit local noise =  1630208
# Right limit local noise =  1651590
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.79691606722864
# ****************************************************************
#
# Injection No. 50
# ----------------------
# Time injection, without jitter (in seconds): 408.0
# Current jitter (in seconds): 0.009765625
# Time injection, with jitter (in seconds): 408.009765625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1662976
# Right limit local noise =  1684358
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  83.43147109195256
# ****************************************************************
#
# Injection No. 51
# ----------------------
# Time injection, without jitter (in seconds): 416.0
# Current jitter (in seconds): -0.0048828125
# Time injection, with jitter (in seconds): 415.9951171875
#
# +++++ SNR calculation +++++
# Left limit local noise =  1695744
# Right limit local noise =  1717126
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  84.71904185065995
# ****************************************************************
#
# Injection No. 52
# ----------------------
# Time injection, without jitter (in seconds): 424.0
# Current jitter (in seconds): -0.00146484375
# Time injection, with jitter (in seconds): 423.99853515625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1728512
# Right limit local noise =  1749894
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.68820065172535
# ****************************************************************
#
# Injection No. 53
# ----------------------
# Time injection, without jitter (in seconds): 432.0
# Current jitter (in seconds): -0.0078125
# Time injection, with jitter (in seconds): 431.9921875
#
# +++++ SNR calculation +++++
# Left limit local noise =  1761280
# Right limit local noise =  1782662
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.10853781003541
# ****************************************************************
#
# Injection No. 54
# ----------------------
# Time injection, without jitter (in seconds): 440.0
# Current jitter (in seconds): 0.005126953125
# Time injection, with jitter (in seconds): 440.005126953125
#
# +++++ SNR calculation +++++
# Left limit local noise =  1794048
# Right limit local noise =  1815430
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.97280940188934
# ****************************************************************
#
# Injection No. 55
# ----------------------
# Time injection, without jitter (in seconds): 448.0
# Current jitter (in seconds): -0.0029296875
# Time injection, with jitter (in seconds): 447.9970703125
#
# +++++ SNR calculation +++++
# Left limit local noise =  1826816
# Right limit local noise =  1848198
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.94093470435148
# ****************************************************************
#
# Injection No. 56
# ----------------------
# Time injection, without jitter (in seconds): 456.0
# Current jitter (in seconds): 0.001220703125
# Time injection, with jitter (in seconds): 456.001220703125
#
# +++++ SNR calculation +++++
# Left limit local noise =  1859584
# Right limit local noise =  1880966
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  83.11620296865414
# ****************************************************************
#
# Injection No. 57
# ----------------------
# Time injection, without jitter (in seconds): 464.0
# Current jitter (in seconds): 0.007568359375
# Time injection, with jitter (in seconds): 464.007568359375
#
# +++++ SNR calculation +++++
# Left limit local noise =  1892352
# Right limit local noise =  1913734
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.42590632108062
# ****************************************************************
#
# Injection No. 58
# ----------------------
# Time injection, without jitter (in seconds): 472.0
# Current jitter (in seconds): -0.00244140625
# Time injection, with jitter (in seconds): 471.99755859375
#
# +++++ SNR calculation +++++
# Left limit local noise =  1925120
# Right limit local noise =  1946502
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.36245409178706
# ****************************************************************
#
# Injection No. 59
# ----------------------
# Time injection, without jitter (in seconds): 480.0
# Current jitter (in seconds): 0.008544921875
# Time injection, with jitter (in seconds): 480.008544921875
#
# +++++ SNR calculation +++++
# Left limit local noise =  1957888
# Right limit local noise =  1979270
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.54703403977449
# ****************************************************************
#
# Injection No. 60
# ----------------------
# Time injection, without jitter (in seconds): 488.0
# Current jitter (in seconds): -0.005859375
# Time injection, with jitter (in seconds): 487.994140625
#
# +++++ SNR calculation +++++
# Left limit local noise =  1990656
# Right limit local noise =  2012038
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.06414045506237
# ****************************************************************
#
# Injection No. 61
# ----------------------
# Time injection, without jitter (in seconds): 496.0
# Current jitter (in seconds): 0.000732421875
# Time injection, with jitter (in seconds): 496.000732421875
#
# +++++ SNR calculation +++++
# Left limit local noise =  2023424
# Right limit local noise =  2044806
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  83.96115453663916
# ****************************************************************
#
# Injection No. 62
# ----------------------
# Time injection, without jitter (in seconds): 504.0
# Current jitter (in seconds): -0.00146484375
# Time injection, with jitter (in seconds): 503.99853515625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2056192
# Right limit local noise =  2077574
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  79.25032990870609
# ****************************************************************
#
# Injection No. 63
# ----------------------
# Time injection, without jitter (in seconds): 512.0
# Current jitter (in seconds): -0.001220703125
# Time injection, with jitter (in seconds): 511.998779296875
#
# +++++ SNR calculation +++++
# Left limit local noise =  2088960
# Right limit local noise =  2110342
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.30019794124489
# ****************************************************************
#
# Injection No. 64
# ----------------------
# Time injection, without jitter (in seconds): 520.0
# Current jitter (in seconds): 0.00244140625
# Time injection, with jitter (in seconds): 520.00244140625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2121728
# Right limit local noise =  2143110
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.42594489609597
# ****************************************************************
#
# Injection No. 65
# ----------------------
# Time injection, without jitter (in seconds): 528.0
# Current jitter (in seconds): 0.0048828125
# Time injection, with jitter (in seconds): 528.0048828125
#
# +++++ SNR calculation +++++
# Left limit local noise =  2154496
# Right limit local noise =  2175878
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.75598417169286
# ****************************************************************
#
# Injection No. 66
# ----------------------
# Time injection, without jitter (in seconds): 536.0
# Current jitter (in seconds): 0.004150390625
# Time injection, with jitter (in seconds): 536.004150390625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2187264
# Right limit local noise =  2208646
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.50006436340988
# ****************************************************************
#
# Injection No. 67
# ----------------------
# Time injection, without jitter (in seconds): 544.0
# Current jitter (in seconds): -0.007080078125
# Time injection, with jitter (in seconds): 543.992919921875
#
# +++++ SNR calculation +++++
# Left limit local noise =  2220032
# Right limit local noise =  2241414
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.14048610563157
# ****************************************************************
#
# Injection No. 68
# ----------------------
# Time injection, without jitter (in seconds): 552.0
# Current jitter (in seconds): 0.006103515625
# Time injection, with jitter (in seconds): 552.006103515625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2252800
# Right limit local noise =  2274182
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.31585722854044
# ****************************************************************
#
# Injection No. 69
# ----------------------
# Time injection, without jitter (in seconds): 560.0
# Current jitter (in seconds): -0.00244140625
# Time injection, with jitter (in seconds): 559.99755859375
#
# +++++ SNR calculation +++++
# Left limit local noise =  2285568
# Right limit local noise =  2306950
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  79.68166038228959
# ****************************************************************
#
# Injection No. 70
# ----------------------
# Time injection, without jitter (in seconds): 568.0
# Current jitter (in seconds): -0.0048828125
# Time injection, with jitter (in seconds): 567.9951171875
#
# +++++ SNR calculation +++++
# Left limit local noise =  2318336
# Right limit local noise =  2339718
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  79.81949350567731
# ****************************************************************
#
# Injection No. 71
# ----------------------
# Time injection, without jitter (in seconds): 576.0
# Current jitter (in seconds): -0.000244140625
# Time injection, with jitter (in seconds): 575.999755859375
#
# +++++ SNR calculation +++++
# Left limit local noise =  2351104
# Right limit local noise =  2372486
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  84.85141749118463
# ****************************************************************
#
# Injection No. 72
# ----------------------
# Time injection, without jitter (in seconds): 584.0
# Current jitter (in seconds): -0.002685546875
# Time injection, with jitter (in seconds): 583.997314453125
#
# +++++ SNR calculation +++++
# Left limit local noise =  2383872
# Right limit local noise =  2405254
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.13093316713305
# ****************************************************************
#
# Injection No. 73
# ----------------------
# Time injection, without jitter (in seconds): 592.0
# Current jitter (in seconds): -0.001708984375
# Time injection, with jitter (in seconds): 591.998291015625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2416640
# Right limit local noise =  2438022
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.64051435096052
# ****************************************************************
#
# Injection No. 74
# ----------------------
# Time injection, without jitter (in seconds): 600.0
# Current jitter (in seconds): -0.0068359375
# Time injection, with jitter (in seconds): 599.9931640625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2449408
# Right limit local noise =  2470790
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  86.41857214317629
# ****************************************************************
#
# Injection No. 75
# ----------------------
# Time injection, without jitter (in seconds): 608.0
# Current jitter (in seconds): 0.005126953125
# Time injection, with jitter (in seconds): 608.005126953125
#
# +++++ SNR calculation +++++
# Left limit local noise =  2482176
# Right limit local noise =  2503558
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.43636703973124
# ****************************************************************
#
# Injection No. 76
# ----------------------
# Time injection, without jitter (in seconds): 616.0
# Current jitter (in seconds): 0.0048828125
# Time injection, with jitter (in seconds): 616.0048828125
#
# +++++ SNR calculation +++++
# Left limit local noise =  2514944
# Right limit local noise =  2536326
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.08686972821876
# ****************************************************************
#
# Injection No. 77
# ----------------------
# Time injection, without jitter (in seconds): 624.0
# Current jitter (in seconds): 0.003173828125
# Time injection, with jitter (in seconds): 624.003173828125
#
# +++++ SNR calculation +++++
# Left limit local noise =  2547712
# Right limit local noise =  2569094
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.50040406505963
# ****************************************************************
#
# Injection No. 78
# ----------------------
# Time injection, without jitter (in seconds): 632.0
# Current jitter (in seconds): 0.0
# Time injection, with jitter (in seconds): 632.0
#
# +++++ SNR calculation +++++
# Left limit local noise =  2580480
# Right limit local noise =  2601862
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.05688278632562
# ****************************************************************
#
# Injection No. 79
# ----------------------
# Time injection, without jitter (in seconds): 640.0
# Current jitter (in seconds): 0.00048828125
# Time injection, with jitter (in seconds): 640.00048828125
#
# +++++ SNR calculation +++++
# Left limit local noise =  2613248
# Right limit local noise =  2634630
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.26393362427926
# ****************************************************************
#
# Injection No. 80
# ----------------------
# Time injection, without jitter (in seconds): 648.0
# Current jitter (in seconds): -0.005859375
# Time injection, with jitter (in seconds): 647.994140625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2646016
# Right limit local noise =  2667398
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.00594812719564
# ****************************************************************
#
# Injection No. 81
# ----------------------
# Time injection, without jitter (in seconds): 656.0
# Current jitter (in seconds): -0.005859375
# Time injection, with jitter (in seconds): 655.994140625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2678784
# Right limit local noise =  2700166
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.04498452854749
# ****************************************************************
#
# Injection No. 82
# ----------------------
# Time injection, without jitter (in seconds): 664.0
# Current jitter (in seconds): -0.003662109375
# Time injection, with jitter (in seconds): 663.996337890625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2711552
# Right limit local noise =  2732934
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.98419154337559
# ****************************************************************
#
# Injection No. 83
# ----------------------
# Time injection, without jitter (in seconds): 672.0
# Current jitter (in seconds): -0.005859375
# Time injection, with jitter (in seconds): 671.994140625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2744320
# Right limit local noise =  2765702
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  83.65165304969109
# ****************************************************************
#
# Injection No. 84
# ----------------------
# Time injection, without jitter (in seconds): 680.0
# Current jitter (in seconds): -0.004150390625
# Time injection, with jitter (in seconds): 679.995849609375
#
# +++++ SNR calculation +++++
# Left limit local noise =  2777088
# Right limit local noise =  2798470
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.35407737553477
# ****************************************************************
#
# Injection No. 85
# ----------------------
# Time injection, without jitter (in seconds): 688.0
# Current jitter (in seconds): 0.00830078125
# Time injection, with jitter (in seconds): 688.00830078125
#
# +++++ SNR calculation +++++
# Left limit local noise =  2809856
# Right limit local noise =  2831238
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.12735890646115
# ****************************************************************
#
# Injection No. 86
# ----------------------
# Time injection, without jitter (in seconds): 696.0
# Current jitter (in seconds): -0.005859375
# Time injection, with jitter (in seconds): 695.994140625
#
# +++++ SNR calculation +++++
# Left limit local noise =  2842624
# Right limit local noise =  2864006
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.64997789106343
# ****************************************************************
#
# Injection No. 87
# ----------------------
# Time injection, without jitter (in seconds): 704.0
# Current jitter (in seconds): -0.00390625
# Time injection, with jitter (in seconds): 703.99609375
#
# +++++ SNR calculation +++++
# Left limit local noise =  2875392
# Right limit local noise =  2896774
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  83.01057404635496
# ****************************************************************
#
# Injection No. 88
# ----------------------
# Time injection, without jitter (in seconds): 712.0
# Current jitter (in seconds): 0.00341796875
# Time injection, with jitter (in seconds): 712.00341796875
#
# +++++ SNR calculation +++++
# Left limit local noise =  2908160
# Right limit local noise =  2929542
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.56326936061343
# ****************************************************************
#
# Injection No. 89
# ----------------------
# Time injection, without jitter (in seconds): 720.0
# Current jitter (in seconds): 0.0068359375
# Time injection, with jitter (in seconds): 720.0068359375
#
# +++++ SNR calculation +++++
# Left limit local noise =  2940928
# Right limit local noise =  2962310
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.94227309413706
# ****************************************************************
#
# Injection No. 90
# ----------------------
# Time injection, without jitter (in seconds): 728.0
# Current jitter (in seconds): 0.00732421875
# Time injection, with jitter (in seconds): 728.00732421875
#
# +++++ SNR calculation +++++
# Left limit local noise =  2973696
# Right limit local noise =  2995078
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.13532180414848
# ****************************************************************
#
# Injection No. 91
# ----------------------
# Time injection, without jitter (in seconds): 736.0
# Current jitter (in seconds): 0.009033203125
# Time injection, with jitter (in seconds): 736.009033203125
#
# +++++ SNR calculation +++++
# Left limit local noise =  3006464
# Right limit local noise =  3027846
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.0664629954145
# ****************************************************************
#
# Injection No. 92
# ----------------------
# Time injection, without jitter (in seconds): 744.0
# Current jitter (in seconds): -0.001708984375
# Time injection, with jitter (in seconds): 743.998291015625
#
# +++++ SNR calculation +++++
# Left limit local noise =  3039232
# Right limit local noise =  3060614
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.9591601339836
# ****************************************************************
#
# Injection No. 93
# ----------------------
# Time injection, without jitter (in seconds): 752.0
# Current jitter (in seconds): -0.00927734375
# Time injection, with jitter (in seconds): 751.99072265625
#
# +++++ SNR calculation +++++
# Left limit local noise =  3072000
# Right limit local noise =  3093382
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  83.30186656873708
# ****************************************************************
#
# Injection No. 94
# ----------------------
# Time injection, without jitter (in seconds): 760.0
# Current jitter (in seconds): -0.006591796875
# Time injection, with jitter (in seconds): 759.993408203125
#
# +++++ SNR calculation +++++
# Left limit local noise =  3104768
# Right limit local noise =  3126150
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.31610080479925
# ****************************************************************
#
# Injection No. 95
# ----------------------
# Time injection, without jitter (in seconds): 768.0
# ...
# Injection SNR value (PyCBC):  81.04832964180535
# ****************************************************************
#
# Injection No. 480
# ----------------------
# Time injection, without jitter (in seconds): 3848.0
# Current jitter (in seconds): -0.001953125
# Time injection, with jitter (in seconds): 3847.998046875
#
# +++++ SNR calculation +++++
# Left limit local noise =  15753216
# Right limit local noise =  15774598
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.67889248890556
# ****************************************************************
#
# Injection No. 481
# ----------------------
# Time injection, without jitter (in seconds): 3856.0
# Current jitter (in seconds): -0.002197265625
# Time injection, with jitter (in seconds): 3855.997802734375
#
# +++++ SNR calculation +++++
# Left limit local noise =  15785984
# Right limit local noise =  15807366
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.59903771932152
# ****************************************************************
#
# Injection No. 482
# ----------------------
# Time injection, without jitter (in seconds): 3864.0
# Current jitter (in seconds): -0.00634765625
# Time injection, with jitter (in seconds): 3863.99365234375
#
# +++++ SNR calculation +++++
# Left limit local noise =  15818752
# Right limit local noise =  15840134
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.19874654004296
# ****************************************************************
#
# Injection No. 483
# ----------------------
# Time injection, without jitter (in seconds): 3872.0
# Current jitter (in seconds): 0.002685546875
# Time injection, with jitter (in seconds): 3872.002685546875
#
# +++++ SNR calculation +++++
# Left limit local noise =  15851520
# Right limit local noise =  15872902
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.55324528788131
# ****************************************************************
#
# Injection No. 484
# ----------------------
# Time injection, without jitter (in seconds): 3880.0
# Current jitter (in seconds): 0.00732421875
# Time injection, with jitter (in seconds): 3880.00732421875
#
# +++++ SNR calculation +++++
# Left limit local noise =  15884288
# Right limit local noise =  15905670
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.31742356857131
# ****************************************************************
#
# Injection No. 485
# ----------------------
# Time injection, without jitter (in seconds): 3888.0
# Current jitter (in seconds): 0.004638671875
# Time injection, with jitter (in seconds): 3888.004638671875
#
# +++++ SNR calculation +++++
# Left limit local noise =  15917056
# Right limit local noise =  15938438
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.83197722380133
# ****************************************************************
#
# Injection No. 486
# ----------------------
# Time injection, without jitter (in seconds): 3896.0
# Current jitter (in seconds): 0.003662109375
# Time injection, with jitter (in seconds): 3896.003662109375
#
# +++++ SNR calculation +++++
# Left limit local noise =  15949824
# Right limit local noise =  15971206
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.14413305427921
# ****************************************************************
#
# Injection No. 487
# ----------------------
# Time injection, without jitter (in seconds): 3904.0
# Current jitter (in seconds): 0.008056640625
# Time injection, with jitter (in seconds): 3904.008056640625
#
# +++++ SNR calculation +++++
# Left limit local noise =  15982592
# Right limit local noise =  16003974
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.32292165517025
# ****************************************************************
#
# Injection No. 488
# ----------------------
# Time injection, without jitter (in seconds): 3912.0
# Current jitter (in seconds): 0.00537109375
# Time injection, with jitter (in seconds): 3912.00537109375
#
# +++++ SNR calculation +++++
# Left limit local noise =  16015360
# Right limit local noise =  16036742
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.34675168720631
# ****************************************************************
#
# Injection No. 489
# ----------------------
# Time injection, without jitter (in seconds): 3920.0
# Current jitter (in seconds): -0.007080078125
# Time injection, with jitter (in seconds): 3919.992919921875
#
# +++++ SNR calculation +++++
# Left limit local noise =  16048128
# Right limit local noise =  16069510
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.64164998392722
# ****************************************************************
#
# Injection No. 490
# ----------------------
# Time injection, without jitter (in seconds): 3928.0
# Current jitter (in seconds): -0.00732421875
# Time injection, with jitter (in seconds): 3927.99267578125
#
# +++++ SNR calculation +++++
# Left limit local noise =  16080896
# Right limit local noise =  16102278
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.8189960756991
# ****************************************************************
#
# Injection No. 491
# ----------------------
# Time injection, without jitter (in seconds): 3936.0
# Current jitter (in seconds): -0.00048828125
# Time injection, with jitter (in seconds): 3935.99951171875
#
# +++++ SNR calculation +++++
# Left limit local noise =  16113664
# Right limit local noise =  16135046
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.54875207289169
# ****************************************************************
#
# Injection No. 492
# ----------------------
# Time injection, without jitter (in seconds): 3944.0
# Current jitter (in seconds): -0.000244140625
# Time injection, with jitter (in seconds): 3943.999755859375
#
# +++++ SNR calculation +++++
# Left limit local noise =  16146432
# Right limit local noise =  16167814
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.27060418148065
# ****************************************************************
#
# Injection No. 493
# ----------------------
# Time injection, without jitter (in seconds): 3952.0
# Current jitter (in seconds): -0.0009765625
# Time injection, with jitter (in seconds): 3951.9990234375
#
# +++++ SNR calculation +++++
# Left limit local noise =  16179200
# Right limit local noise =  16200582
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.42688371620714
# ****************************************************************
#
# Injection No. 494
# ----------------------
# Time injection, without jitter (in seconds): 3960.0
# Current jitter (in seconds): -0.00341796875
# Time injection, with jitter (in seconds): 3959.99658203125
#
# +++++ SNR calculation +++++
# Left limit local noise =  16211968
# Right limit local noise =  16233350
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.4855341923412
# ****************************************************************
#
# Injection No. 495
# ----------------------
# Time injection, without jitter (in seconds): 3968.0
# Current jitter (in seconds): 0.006103515625
# Time injection, with jitter (in seconds): 3968.006103515625
#
# +++++ SNR calculation +++++
# Left limit local noise =  16244736
# Right limit local noise =  16266118
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.5391808376364
# ****************************************************************
#
# Injection No. 496
# ----------------------
# Time injection, without jitter (in seconds): 3976.0
# Current jitter (in seconds): -0.0029296875
# Time injection, with jitter (in seconds): 3975.9970703125
#
# +++++ SNR calculation +++++
# Left limit local noise =  16277504
# Right limit local noise =  16298886
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.05210194598826
# ****************************************************************
#
# Injection No. 497
# ----------------------
# Time injection, without jitter (in seconds): 3984.0
# Current jitter (in seconds): -0.003173828125
# Time injection, with jitter (in seconds): 3983.996826171875
#
# +++++ SNR calculation +++++
# Left limit local noise =  16310272
# Right limit local noise =  16331654
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.02969074590939
# ****************************************************************
#
# Injection No. 498
# ----------------------
# Time injection, without jitter (in seconds): 3992.0
# Current jitter (in seconds): -0.00732421875
# Time injection, with jitter (in seconds): 3991.99267578125
#
# +++++ SNR calculation +++++
# Left limit local noise =  16343040
# Right limit local noise =  16364422
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.7512888102125
# ****************************************************************
#
# Injection No. 499
# ----------------------
# Time injection, without jitter (in seconds): 4000.0
# Current jitter (in seconds): 0.003173828125
# Time injection, with jitter (in seconds): 4000.003173828125
#
# +++++ SNR calculation +++++
# Left limit local noise =  16375808
# Right limit local noise =  16397190
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.42244116973225
# ****************************************************************
#
# Injection No. 500
# ----------------------
# Time injection, without jitter (in seconds): 4008.0
# Current jitter (in seconds): 0.00048828125
# Time injection, with jitter (in seconds): 4008.00048828125
#
# +++++ SNR calculation +++++
# Left limit local noise =  16408576
# Right limit local noise =  16429958
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  83.51016437726219
# ****************************************************************
#
# Injection No. 501
# ----------------------
# Time injection, without jitter (in seconds): 4016.0
# Current jitter (in seconds): 0.00634765625
# Time injection, with jitter (in seconds): 4016.00634765625
#
# +++++ SNR calculation +++++
# Left limit local noise =  16441344
# Right limit local noise =  16462726
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.22778530537192
# ****************************************************************
#
# Injection No. 502
# ----------------------
# Time injection, without jitter (in seconds): 4024.0
# Current jitter (in seconds): 0.001220703125
# Time injection, with jitter (in seconds): 4024.001220703125
#
# +++++ SNR calculation +++++
# Left limit local noise =  16474112
# Right limit local noise =  16495494
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.09260938918094
# ****************************************************************
#
# Injection No. 503
# ----------------------
# Time injection, without jitter (in seconds): 4032.0
# Current jitter (in seconds): 0.004638671875
# Time injection, with jitter (in seconds): 4032.004638671875
#
# +++++ SNR calculation +++++
# Left limit local noise =  16506880
# Right limit local noise =  16528262
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.46028177017398
# ****************************************************************
#
# Injection No. 504
# ----------------------
# Time injection, without jitter (in seconds): 4040.0
# Current jitter (in seconds): 0.005615234375
# Time injection, with jitter (in seconds): 4040.005615234375
#
# +++++ SNR calculation +++++
# Left limit local noise =  16539648
# Right limit local noise =  16561030
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.62623680490512
# ****************************************************************
#
# Injection No. 505
# ----------------------
# Time injection, without jitter (in seconds): 4048.0
# Current jitter (in seconds): -0.0078125
# Time injection, with jitter (in seconds): 4047.9921875
#
# +++++ SNR calculation +++++
# Left limit local noise =  16572416
# Right limit local noise =  16593798
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.03435693520171
# ****************************************************************
#
# Injection No. 506
# ----------------------
# Time injection, without jitter (in seconds): 4056.0
# Current jitter (in seconds): 0.001220703125
# Time injection, with jitter (in seconds): 4056.001220703125
#
# +++++ SNR calculation +++++
# Left limit local noise =  16605184
# Right limit local noise =  16626566
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  81.30864661573153
# ****************************************************************
#
# Injection No. 507
# ----------------------
# Time injection, without jitter (in seconds): 4064.0
# Current jitter (in seconds): -0.000732421875
# Time injection, with jitter (in seconds): 4063.999267578125
#
# +++++ SNR calculation +++++
# Left limit local noise =  16637952
# Right limit local noise =  16659334
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  79.9130760810869
# ****************************************************************
#
# Injection No. 508
# ----------------------
# Time injection, without jitter (in seconds): 4072.0
# Current jitter (in seconds): -0.003173828125
# Time injection, with jitter (in seconds): 4071.996826171875
#
# +++++ SNR calculation +++++
# Left limit local noise =  16670720
# Right limit local noise =  16692102
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.55562700869504
# ****************************************************************
#
# Injection No. 509
# ----------------------
# Time injection, without jitter (in seconds): 4080.0
# Current jitter (in seconds): -0.005615234375
# Time injection, with jitter (in seconds): 4079.994384765625
#
# +++++ SNR calculation +++++
# Left limit local noise =  16703488
# Right limit local noise =  16724870
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  80.89787465389408
# ****************************************************************
#
# Injection No. 510
# ----------------------
# Time injection, without jitter (in seconds): 4088.0
# Current jitter (in seconds): 0.0087890625
# Time injection, with jitter (in seconds): 4088.0087890625
#
# +++++ SNR calculation +++++
# Left limit local noise =  16736256
# Right limit local noise =  16757638
# Strain noise length (in sample units): 16777216
# Strain noise segment length (in sample units): 21383
# Injection SNR value (PyCBC):  82.20974873699409
# ****************************************************************

# %%
# ------> Rename arrays to pass them to next section

t = time_n               # Time
s_raw =  strain_n_new    # Raw strain data

# %% [markdown]
# ## 3. Pre-process Data

# %% [markdown]
# ### 3.1. Input parameters

# %%
# Filter's frequency band
# ------------------------------------------------------------
set_band = np.array([100,1800])  # frequency band (in Hz)
# ------------------------------------------------------------

# Remark, about the frequency band:
# This choice is important, in order to capture g-mode, which cover a wide
# region in the frequency domain. It is important to guide our choise in
# the original TF plots for the waveforms before injected to noise.

# %% [markdown]
# ### 3.1. Pre-processing preparation

# %%
# ------> Count samples in the data segment

Nsamples = len(t)
print("Num of samples in raw strain segment: ", Nsamples)

# ------> Check

if Nsamples % 2 == 1:
    raise ValueError('Nsamples is odd')

# ------> Compute sampling freq and time

fs = 1 / (t[1]-t[0])  # Sampling frequency
ts = 1 / fs           # sampling time
# Out:
# Num of samples in raw strain segment:  16777216

# %% [markdown]
# ### 3.2. Whitening application

# %%
# ------> Whitening input parameters

doplots_white = 0     # Do plots for check

seg = 4.0 #0.5              # Welch's segments size (in seconds)
nperseg = int(seg*fs)       # Welch's segments size (in sample units)
nfft = Nsamples             # FFT size (in sample units)

# Only for PyCBC implementation

cut = 10.0 # This is the cut's length (in seconds) to remove edge artifacts
           # in whitened strain data: (cut/2) at left edge, (cut/2) at right edge

# %%
# ------> Apply whitening to raw strain data

s_white_t, psd_raw, fpsd_raw, psd_white, fpsd_white = whitening_PyCBC(s_raw, seg, cut, ts, doplots_white)

t_white = s_white_t.sample_times

# %%
# ------> Convert PyCBC elements to numpy arrays

t_white = np.array(t_white, dtype='float64')
s_white_t = np.array(s_white_t, dtype='float64')
psd_white = np.array(psd_white, dtype='float64')
fpsd_white = np.array(fpsd_white, dtype='float64')

# %% [markdown]
# ### 3.3. Band-pass filtering application

# %%
# ------> Input parameters

doplots_bp = 0              # Do plots for check
n_order = 8                 # Filter's order
band = set_band

seg = 4.0 #0.5              # Welch's segments size (in seconds)
nperseg = int(seg*fs)       # Welch's segments size (in sample units)

# %%
# ------> Apply band-pass filtering to whitened strain data

s_filt_t, psd_filt, fpsd_filt = filt_bandpass_PyCBC(s_white_t, n_order, band, ts, seg, doplots_bp)

t_filt = s_filt_t.sample_times

# %%
# ------> Convert PyCBC elements to numpy arrays

t_filt = np.array(t_filt, dtype='float64')
s_filt_t = np.array(s_filt_t, dtype='float64')
psd_filt = np.array(psd_filt, dtype='float64')
fpsd_filt = np.array(fpsd_filt, dtype='float64')

# ------> Displace time of filtered strain data

t_filt = t_filt + t_white[0]

# %% [markdown]
# ### 3.4. Sanity checks

# %% [markdown]
# #### 3.4.1. Spectrogram: White+Filt

# %%
# ------> Check: Plot spectrogram

# Remark: This visual check is useful for a noise segment with a few injections

doplot_spectrogram = 0

wnd="hamming" # Window for spectrograms

if doplot_spectrogram:
    
    freq, time, Sxx = signal.spectrogram(s_filt_t, fs, window=wnd, nperseg=1024)
    #time, freq, WL = WaveletTF_transform(s_filt_t, fs, 1, 2000, 5, 7, 0)
    
    plt.figure(1,figsize=(6.5,5))
    plt.pcolormesh(time+t_filt[0], freq, Sxx, shading='gouraud')
    plt.ylabel('Frequency [Hz]', fontsize=14)
    plt.xlabel('Time [sec]', fontsize=14)
    plt.show()
    plt.figure(2).clear()
    gc.collect(1)

# %% [markdown]
# #### 3.4.2. Strain data: Raw, White, Whit+Filt

# %%
doplot_strains = 1

# ------> Check: Plot raw/whitened/filtered strain data

if doplot_strains:
    
        
    t_min = np.min(t); t_max = np.max(t)
    
    plt.figure(1, figsize=(8,5))
    plt.plot(t, s_raw)
    plt.title("S raw strain data", fontsize=18)
    plt.ylabel("Strain (unitless)", fontsize=13)
    plt.xlabel("time (seconds)", fontsize=13)
    plt.xlim(left=t_min, right=t_max)
    plt.show()
    plt.figure(1).clear()
    gc.collect()

    plt.figure(2, figsize=(8,5))
    plt.plot(t_white, s_white_t)
    plt.title("S whitened strain data", fontsize=18)
    plt.ylabel("Strain (unitless)", fontsize=13)
    plt.xlabel("time (seconds)", fontsize=13)
    plt.xlim(left=t_min, right=t_max)
    plt.show()
    plt.figure(2).clear()
    gc.collect()

    plt.figure(3, figsize=(8,5))
    plt.plot(t_filt, s_filt_t)
    plt.title("S whitened + filtered strain data", fontsize=18)
    plt.ylabel("Strain (unitless)", fontsize=13)
    plt.xlabel("time (seconds)", fontsize=13)
    plt.xlim(left=t_min, right=t_max)
    plt.show()
    plt.figure(3).clear()
    gc.collect()

# %% [markdown]
# #### 3.4.3 Amplited Spectral Density (ASD)

# %%
# ------> Compute ASD quantities

# Raw strain data ASD
# ---------------------

asd_raw = np.sqrt(psd_raw)

# Whitened strain data ASD
# --------------------------

asd_white = np.sqrt(psd_white)

# Filtered strain data ASD
# --------------------------

asd_filt = np.sqrt(psd_filt)

# %%
# Plot ADS for raw/whitened/filtered strain data

#mpl.rcParams['agg.path.chunksize'] = 10000

plt.figure(figsize=(7.75,5))
plt.plot(fpsd_raw, asd_raw, label='ASD raw')
plt.plot(fpsd_white, asd_white, label='ASD white')
plt.plot(fpsd_filt, asd_filt, label='ASD white+filter')
#plt.xlim(left=9)
plt.xscale('log')
plt.yscale('log')
plt.title("ASD", fontsize=18)
plt.ylabel("Amplitude Spectral Density", fontsize=13)
plt.xlabel("frequency", fontsize=13)
plt.legend()
plt.show()
plt.figure().clear()
gc.collect()
# Out:
# 14550

# %%
# ------> Rename arrays to pass them to next section

t = t_filt      # Time
s = s_filt_t    # Pre-processed strain data

# %% [markdown]
# ## 4. Build Strain Data

# %% [markdown]
# ### 4.1. Input parameters

# %%
# ------> Input parameters for window samples generation

# Scalar parameter in window time for samples (in seconds)
# ------------------------------------------------------------
alpha = 0.02001    # alpha must be greater than 2*jitter_lim
# ------------------------------------------------------------

# Range for SNR values
# --------------------------------------------------------------------
SNR_max = 100.0    # Options: 100 (high SNRs), 50 (low SNRs)
SNR_min = 0.0    # Options: 0 (high SNRs); 12 (low SNRs)
# --------------------------------------------------------------------

# Plot windows samples (time & TF domain)
# ------------------------------------------------------------
set_doplots = 0    #  1: yes | 0: no
# ------------------------------------------------------------

# %%
# ------> Check

if alpha <= 2*jitter_lim:
    print("")
    print("******** Error: alpha must be greater than 2*jitter_lim ********")
    print("")
    
    raise SystemExit("Code stopped here!")
    
else:
    pass

# Remark: The condition alpha > 2*jitter_lim ensures that
#         the whole injected waveform will be in the window sample.

# %% [markdown]
# ### 4.2. Window samples preparation

# %%
# ------> Compute maximum waveform duration (in seconds)

# Remark: For this calculation, we consider all waveforms saved on Waveforms folder

waveforms_dir = "/home/manuel/Research Projects/GW Data analysis/GitHub/CCSNeHFGW_ResNetClass/Waveforms_mod/Phen/"

# Load waveforms log data dictionary
with open(waveforms_dir + "waveforms_log.pkl", 'rb') as fp:
    waveforms_log = pickle.load(fp)
    
# Extract duration of all waveforms

wf_duration_all = []

label = ["class 1", "class 2", "class 3"]

for class_wf in label:
    for i in range(len(waveforms_log[class_wf])):
        wf_duration_i = waveforms_log[class_wf][i][3]
        wf_duration_all.append(float(wf_duration_i))

# Compute maximum duration
        
wf_max = max(wf_duration_all)

# %%
# ------> Define a UNIQUE time window duration (in seconds)

Twin = wf_max + alpha

Twin_rounded = math.ceil(Twin * 1e5) / 1e5

# %%
# ------> Print waveforms information

print("Maximum waveform duration (in seconds)")
print("wf_max = ", wf_max)
print("")
print("Alpha scalar parameter (in seconds)")
print("alpha = ", alpha)
print("")
print("Duration of window strain samples (in seconds)")
print("Twin = wf_max + alpha = ", Twin)
print("Twin rounded = ", Twin_rounded)

# Use Twin_rounded hereinafter

Twin = Twin_rounded
# Out:
# Maximum waveform duration (in seconds)
# wf_max =  0.94970703125
#
# Alpha scalar parameter (in seconds)
# alpha =  0.02001
#
# Duration of window strain samples (in seconds)
# Twin = wf_max + alpha =  0.96971703125
# Twin rounded =  0.96972

# %%
# ------> Recover information from log_data file

inj_time = []
jitt = []
SNR_waveform = []
duration_wf = []

for i in range(len(log_data)):
    inj_time.append(log_data[i][0])
    jitt.append(log_data[i][1])
    SNR_waveform.append(log_data[i][2])
    duration_wf.append(log_data[i][3])

# %%
# ------> Convert lists to numpy arrays, clear memory from lists

t_inj = np.array(inj_time, dtype='float64')
del(inj_time)
gc.collect()

jitter = np.array(jitt, dtype='float64')
del(jitt)
gc.collect()

wf_SNR = np.array(SNR_waveform, dtype='float64')
del(SNR_waveform)
gc.collect()

wf_duration = np.array(duration_wf, dtype='float64')
del(duration_wf)
gc.collect()
# Out:
# 0

# %%
# ------> Initialize array for initial times of each sample window

Twin_ini = np.zeros(len(t_inj))

# ------> Populate above array with time values

for i in range(len(t_inj)): # Select all windows
#for i in range(10): # Select only a few windows
    
    # Remark: The following expression ensures beforehand that each window sample
    #         is such that its injection, without jitter variation, is centered.
    
    #Twin_ini[i] =  t_inj[i] + 0.5 * ( wf_duration[i] - Twin ) - jitter[i]
    #print(Twin_ini[i])
    
    # Alternative: Window samples starting 
    
    Twin_ini[i] =  t_inj[i] - abs(jitter[i])

# %%
# ------> Check if window samples at the edges are in the segment

# RIGHT edge of data segment
for i in range(len(Twin_ini)):
    
    if Twin_ini[0] < t[0]:
        print("****** WARNING: Sample at LEFT edge is outside the data segment, it will be removed")
        Twin_ini = np.delete(Twin_ini,0)
        # We also remove the injection
        t_inj = np.delete(t_inj,0)
    else:
        print("End LEFT segment check")
        break

# RIGHT edge of data segment
for i in range(len(Twin_ini)):
    
    #if Twin_ini[-i-1] + Twin > t[-i-1]: # SE CORRIGIO ESTO!!!!
    if Twin_ini[-1] + Twin > t[-1]: 
        print("****** WARNING: Sample at RIGHT edge is outside the data segment, it will be removed")
        #Twin_ini = np.delete(Twin_ini,-i-1) # SE CORRIGIO ESTO!!!!
        Twin_ini = np.delete(Twin_ini,-1)
        # We also remove the injection
        t_inj = np.delete(t_inj,-i-1)
    else:
        print("End RIGHT segment check")
        break
# Out:
# End LEFT segment check
# End RIGHT segment check

# %%
# ------> Convert Twin_ini values (in seconds) to locating indexes

ts = t[1]-t[0]

locate_win = np.zeros(len(Twin_ini))

for i in range(len(Twin_ini)):    
    locate_win[i] = int(Twin_ini[i]/ts) - int(t[0]/ts)

locate_win = locate_win.astype(int)

# %%
# ------> Checks: Twin_ini vs. t_inj

print("Length of vector for time injections: ", len(t_inj))
print("Length of vector for windows's initial time: ", len(Twin_ini))
#print("Length of locate_win vector : ", len(locate_win))
print("Length of window samples (in seconds) : ", Twin)

for i in range(len(Twin_ini)):
    if t_inj[i] <= Twin_ini[i]:
        print("")
        print("****** WARNING: At sample", i, "Injection's start is outside the window (LEFT)")
        print("Window's initial time (seconds) =", Twin_ini[i])
        print("Injection initial time (seconds) =", t_inj[i])
        print("----------------------------------------------")
        print("")
    elif t_inj[i]+wf_duration[i] >= Twin_ini[i]+Twin:
        print("****** WARNING: At sample", i, "Injection's end is outside the window (RIGHT)")
        print("Window's end time (seconds) =", Twin_ini[i]+Twin)
        print("Injection end time (seconds) =", t_inj[i]+wf_duration[i])
        print("----------------------------------------------")
        print("")
    else:
        #print("")
        #print("Sample", i)
        #print("Window's initial time (seconds) =", Twin_ini[i])
        #print("----------------------------------------")
        #print("Injection initial time (seconds) =", t_inj[i])
        #print("Injection end time (seconds) =", t_inj[i]+wf_duration[i])
        #print("----------------------------------------")
        #print("Window's end time (seconds) =", Twin_ini[i]+Twin)
        #print("")
        pass

#for i in range(len(locate_win)):
#for i in range(5):
#    print(Twin_ini[i])
#    print(t[locate_win[i]])
#    print(t_inj[i])
#    print("")
# Out:
# Length of vector for time injections:  511
# Length of vector for windows's initial time:  511
# Length of window samples (in seconds) :  0.96972
# ****** WARNING: At sample 0 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 8.96972
# Injection end time (seconds) = 9.223388671875
# ----------------------------------------------
#
# ****** WARNING: At sample 1 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 16.96972
# Injection end time (seconds) = 17.2294921875
# ----------------------------------------------
#
# ****** WARNING: At sample 2 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 24.96972
# Injection end time (seconds) = 25.22021484375
# ----------------------------------------------
#
# ****** WARNING: At sample 3 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 32.96972
# Injection end time (seconds) = 33.22265625
# ----------------------------------------------
#
# ****** WARNING: At sample 4 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 40.95751296875
# Injection end time (seconds) = 41.2138671875
# ----------------------------------------------
#
# ****** WARNING: At sample 5 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 48.96972
# Injection end time (seconds) = 49.22509765625
# ----------------------------------------------
#
# ****** WARNING: At sample 6 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 56.96434890625
# Injection end time (seconds) = 57.21728515625
# ----------------------------------------------
#
# ****** WARNING: At sample 7 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 64.96972
# Injection end time (seconds) = 65.222412109375
# ----------------------------------------------
#
# ****** WARNING: At sample 8 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 72.96972
# Injection end time (seconds) = 73.228759765625
# ----------------------------------------------
#
# ****** WARNING: At sample 9 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 80.967766875
# Injection end time (seconds) = 81.218994140625
# ----------------------------------------------
#
# ****** WARNING: At sample 10 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 88.9619075
# Injection end time (seconds) = 89.216064453125
# ----------------------------------------------
#
# ****** WARNING: At sample 11 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 96.95751296875
# Injection end time (seconds) = 97.2138671875
# ----------------------------------------------
#
# ****** WARNING: At sample 12 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 104.96972
# Injection end time (seconds) = 105.22119140625
# ----------------------------------------------
#
# ****** WARNING: At sample 13 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 112.95848953125
# Injection end time (seconds) = 113.21435546875
# ----------------------------------------------
#
# ****** WARNING: At sample 14 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 120.96972
# Injection end time (seconds) = 121.22802734375
# ----------------------------------------------
#
# ****** WARNING: At sample 15 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 128.96434890625
# Injection end time (seconds) = 129.21728515625
# ----------------------------------------------
#
# ****** WARNING: At sample 16 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 136.96972
# Injection end time (seconds) = 137.22705078125
# ----------------------------------------------
#
# ****** WARNING: At sample 17 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 144.96972
# Injection end time (seconds) = 145.222900390625
# ----------------------------------------------
#
# ****** WARNING: At sample 18 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 152.96239578125
# Injection end time (seconds) = 153.21630859375
# ----------------------------------------------
#
# ****** WARNING: At sample 19 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 160.95555984375
# Injection end time (seconds) = 161.212890625
# ----------------------------------------------
#
# ****** WARNING: At sample 20 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 168.95263015625
# Injection end time (seconds) = 169.21142578125
# ----------------------------------------------
#
# ****** WARNING: At sample 21 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 176.96972
# Injection end time (seconds) = 177.22412109375
# ----------------------------------------------
#
# ****** WARNING: At sample 22 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 184.96972
# Injection end time (seconds) = 185.22705078125
# ----------------------------------------------
#
# ****** WARNING: At sample 23 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 192.96972
# Injection end time (seconds) = 193.222412109375
# ----------------------------------------------
#
# ****** WARNING: At sample 24 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 200.96972
# Injection end time (seconds) = 201.22216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 25 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 208.9570246875
# Injection end time (seconds) = 209.213623046875
# ----------------------------------------------
#
# ****** WARNING: At sample 26 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 216.96972
# Injection end time (seconds) = 217.2216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 27 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 224.96972
# Injection end time (seconds) = 225.223388671875
# ----------------------------------------------
#
# ****** WARNING: At sample 28 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 232.9589778125
# Injection end time (seconds) = 233.214599609375
# ----------------------------------------------
#
# ****** WARNING: At sample 29 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 240.96581375
# Injection end time (seconds) = 241.218017578125
# ----------------------------------------------
#
# ****** WARNING: At sample 30 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 248.96727859375
# Injection end time (seconds) = 249.21875
# ----------------------------------------------
#
# ****** WARNING: At sample 31 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 256.956048125
# Injection end time (seconds) = 257.213134765625
# ----------------------------------------------
#
# ****** WARNING: At sample 32 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 264.96972
# Injection end time (seconds) = 265.22900390625
# ----------------------------------------------
#
# ****** WARNING: At sample 33 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 272.9589778125
# Injection end time (seconds) = 273.214599609375
# ----------------------------------------------
#
# ****** WARNING: At sample 34 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 280.956048125
# Injection end time (seconds) = 281.213134765625
# ----------------------------------------------
#
# ****** WARNING: At sample 35 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 288.96825515625
# Injection end time (seconds) = 289.21923828125
# ----------------------------------------------
#
# ****** WARNING: At sample 36 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 296.9511653125
# Injection end time (seconds) = 297.210693359375
# ----------------------------------------------
#
# ****** WARNING: At sample 37 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 304.9667903125
# Injection end time (seconds) = 305.218505859375
# ----------------------------------------------
#
# ****** WARNING: At sample 38 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 312.96972
# Injection end time (seconds) = 313.221435546875
# ----------------------------------------------
#
# ****** WARNING: At sample 39 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 320.95018875
# Injection end time (seconds) = 321.210205078125
# ----------------------------------------------
#
# ****** WARNING: At sample 40 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 328.96630203125
# Injection end time (seconds) = 329.21826171875
# ----------------------------------------------
#
# ****** WARNING: At sample 41 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 336.96972
# Injection end time (seconds) = 337.22509765625
# ----------------------------------------------
#
# ****** WARNING: At sample 42 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 344.95458328125
# Injection end time (seconds) = 345.21240234375
# ----------------------------------------------
#
# ****** WARNING: At sample 43 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 352.967766875
# Injection end time (seconds) = 353.218994140625
# ----------------------------------------------
#
# ****** WARNING: At sample 44 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 360.96972
# Injection end time (seconds) = 361.22509765625
# ----------------------------------------------
#
# ****** WARNING: At sample 45 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 368.959954375
# Injection end time (seconds) = 369.215087890625
# ----------------------------------------------
#
# ****** WARNING: At sample 46 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 376.96972
# Injection end time (seconds) = 377.2265625
# ----------------------------------------------
#
# ****** WARNING: At sample 47 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 384.95067703125
# Injection end time (seconds) = 385.21044921875
# ----------------------------------------------
#
# ****** WARNING: At sample 48 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 392.96972
# Injection end time (seconds) = 393.227783203125
# ----------------------------------------------
#
# ****** WARNING: At sample 49 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 400.96972
# Injection end time (seconds) = 401.2265625
# ----------------------------------------------
#
# ****** WARNING: At sample 50 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 408.96972
# Injection end time (seconds) = 409.229736328125
# ----------------------------------------------
#
# ****** WARNING: At sample 51 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 416.959954375
# Injection end time (seconds) = 417.215087890625
# ----------------------------------------------
#
# ****** WARNING: At sample 52 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 424.9667903125
# Injection end time (seconds) = 425.218505859375
# ----------------------------------------------
#
# ****** WARNING: At sample 53 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 432.954095
# Injection end time (seconds) = 433.212158203125
# ----------------------------------------------
#
# ****** WARNING: At sample 54 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 440.96972
# Injection end time (seconds) = 441.22509765625
# ----------------------------------------------
#
# ****** WARNING: At sample 55 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 448.963860625
# Injection end time (seconds) = 449.217041015625
# ----------------------------------------------
#
# ****** WARNING: At sample 56 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 456.96972
# Injection end time (seconds) = 457.22119140625
# ----------------------------------------------
#
# ****** WARNING: At sample 57 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 464.96972
# Injection end time (seconds) = 465.2275390625
# ----------------------------------------------
#
# ****** WARNING: At sample 58 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 472.9648371875
# Injection end time (seconds) = 473.217529296875
# ----------------------------------------------
#
# ****** WARNING: At sample 59 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 480.96972
# Injection end time (seconds) = 481.228515625
# ----------------------------------------------
#
# ****** WARNING: At sample 60 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 488.95800125
# Injection end time (seconds) = 489.214111328125
# ----------------------------------------------
#
# ****** WARNING: At sample 61 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 496.96972
# Injection end time (seconds) = 497.220703125
# ----------------------------------------------
#
# ****** WARNING: At sample 62 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 504.9667903125
# Injection end time (seconds) = 505.218505859375
# ----------------------------------------------
#
# ****** WARNING: At sample 63 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 512.96727859375
# Injection end time (seconds) = 513.21875
# ----------------------------------------------
#
# ****** WARNING: At sample 64 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 520.96972
# Injection end time (seconds) = 521.222412109375
# ----------------------------------------------
#
# ****** WARNING: At sample 65 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 528.96972
# Injection end time (seconds) = 529.224853515625
# ----------------------------------------------
#
# ****** WARNING: At sample 66 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 536.96972
# Injection end time (seconds) = 537.22412109375
# ----------------------------------------------
#
# ****** WARNING: At sample 67 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 544.95555984375
# Injection end time (seconds) = 545.212890625
# ----------------------------------------------
#
# ****** WARNING: At sample 68 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 552.96972
# Injection end time (seconds) = 553.22607421875
# ----------------------------------------------
#
# ****** WARNING: At sample 69 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 560.9648371875
# Injection end time (seconds) = 561.217529296875
# ----------------------------------------------
#
# ****** WARNING: At sample 70 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 568.959954375
# Injection end time (seconds) = 569.215087890625
# ----------------------------------------------
#
# ****** WARNING: At sample 71 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 576.96923171875
# Injection end time (seconds) = 577.2197265625
# ----------------------------------------------
#
# ****** WARNING: At sample 72 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 584.96434890625
# Injection end time (seconds) = 585.21728515625
# ----------------------------------------------
#
# ****** WARNING: At sample 73 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 592.96630203125
# Injection end time (seconds) = 593.21826171875
# ----------------------------------------------
#
# ****** WARNING: At sample 74 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 600.956048125
# Injection end time (seconds) = 601.213134765625
# ----------------------------------------------
#
# ****** WARNING: At sample 75 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 608.96972
# Injection end time (seconds) = 609.22509765625
# ----------------------------------------------
#
# ****** WARNING: At sample 76 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 616.96972
# Injection end time (seconds) = 617.224853515625
# ----------------------------------------------
#
# ****** WARNING: At sample 77 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 624.96972
# Injection end time (seconds) = 625.22314453125
# ----------------------------------------------
#
#
# ****** WARNING: At sample 78 Injection's start is outside the window (LEFT)
# Window's initial time (seconds) = 632.0
# Injection initial time (seconds) = 632.0
# ----------------------------------------------
#
# ****** WARNING: At sample 79 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 640.96972
# Injection end time (seconds) = 641.220458984375
# ----------------------------------------------
#
# ****** WARNING: At sample 80 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 648.95800125
# Injection end time (seconds) = 649.214111328125
# ----------------------------------------------
#
# ****** WARNING: At sample 81 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 656.95800125
# Injection end time (seconds) = 657.214111328125
# ----------------------------------------------
#
# ****** WARNING: At sample 82 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 664.96239578125
# Injection end time (seconds) = 665.21630859375
# ----------------------------------------------
#
# ****** WARNING: At sample 83 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 672.95800125
# Injection end time (seconds) = 673.214111328125
# ----------------------------------------------
#
# ****** WARNING: At sample 84 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 680.96141921875
# Injection end time (seconds) = 681.2158203125
# ----------------------------------------------
#
# ****** WARNING: At sample 85 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 688.96972
# Injection end time (seconds) = 689.228271484375
# ----------------------------------------------
#
# ****** WARNING: At sample 86 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 696.95800125
# Injection end time (seconds) = 697.214111328125
# ----------------------------------------------
#
# ****** WARNING: At sample 87 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 704.9619075
# Injection end time (seconds) = 705.216064453125
# ----------------------------------------------
#
# ****** WARNING: At sample 88 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 712.96972
# Injection end time (seconds) = 713.223388671875
# ----------------------------------------------
#
# ****** WARNING: At sample 89 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 720.96972
# Injection end time (seconds) = 721.226806640625
# ----------------------------------------------
#
# ****** WARNING: At sample 90 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 728.96972
# Injection end time (seconds) = 729.227294921875
# ----------------------------------------------
#
# ****** WARNING: At sample 91 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 736.96972
# Injection end time (seconds) = 737.22900390625
# ----------------------------------------------
#
# ****** WARNING: At sample 92 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 744.96630203125
# Injection end time (seconds) = 745.21826171875
# ----------------------------------------------
#
# ****** WARNING: At sample 93 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 752.9511653125
# Injection end time (seconds) = 753.210693359375
# ----------------------------------------------
#
# ****** WARNING: At sample 94 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 760.95653640625
# Injection end time (seconds) = 761.21337890625
# ----------------------------------------------
#
# ****** WARNING: At sample 95 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 768.967766875
# Injection end time (seconds) = 769.218994140625
# ----------------------------------------------
#
# ****** WARNING: At sample 96 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 776.96972
# Injection end time (seconds) = 777.227783203125
# ----------------------------------------------
#
# ****** WARNING: At sample 97 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 784.96434890625
# Injection end time (seconds) = 785.21728515625
# ----------------------------------------------
#
# ****** WARNING: At sample 98 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 792.95946609375
# Injection end time (seconds) = 793.21484375
# ----------------------------------------------
#
# ****** WARNING: At sample 99 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 800.96972
# Injection end time (seconds) = 801.227294921875
# ----------------------------------------------
#
# ****** WARNING: At sample 100 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 808.96923171875
# Injection end time (seconds) = 809.2197265625
# ----------------------------------------------
#
# ****** WARNING: At sample 101 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 816.95018875
# Injection end time (seconds) = 817.210205078125
# ----------------------------------------------
#
# ****** WARNING: At sample 102 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 824.96972
# Injection end time (seconds) = 825.2236328125
# ----------------------------------------------
#
#
# ****** WARNING: At sample 103 Injection's start is outside the window (LEFT)
# Window's initial time (seconds) = 832.0
# Injection initial time (seconds) = 832.0
# ----------------------------------------------
#
# ****** WARNING: At sample 104 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 840.96972
# Injection end time (seconds) = 841.22021484375
# ----------------------------------------------
#
# ****** WARNING: At sample 105 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 848.96972
# Injection end time (seconds) = 849.2294921875
# ----------------------------------------------
#
# ****** WARNING: At sample 106 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 856.96337234375
# Injection end time (seconds) = 857.216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 107 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 864.96972
# Injection end time (seconds) = 865.22900390625
# ----------------------------------------------
#
# ****** WARNING: At sample 108 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 872.96972
# Injection end time (seconds) = 873.223876953125
# ----------------------------------------------
#
# ****** WARNING: At sample 109 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 880.95263015625
# Injection end time (seconds) = 881.21142578125
# ----------------------------------------------
#
# ****** WARNING: At sample 110 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 888.96972
# Injection end time (seconds) = 889.22412109375
# ----------------------------------------------
#
# ****** WARNING: At sample 111 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 896.96972
# Injection end time (seconds) = 897.22314453125
# ----------------------------------------------
#
# ****** WARNING: At sample 112 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 904.96337234375
# Injection end time (seconds) = 905.216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 113 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 912.95555984375
# Injection end time (seconds) = 913.212890625
# ----------------------------------------------
#
# ****** WARNING: At sample 114 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 920.963860625
# Injection end time (seconds) = 921.217041015625
# ----------------------------------------------
#
# ****** WARNING: At sample 115 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 928.96972
# Injection end time (seconds) = 929.227783203125
# ----------------------------------------------
#
# ****** WARNING: At sample 116 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 936.96972
# Injection end time (seconds) = 937.225830078125
# ----------------------------------------------
#
# ****** WARNING: At sample 117 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 944.96972
# Injection end time (seconds) = 945.228515625
# ----------------------------------------------
#
# ****** WARNING: At sample 118 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 952.96337234375
# Injection end time (seconds) = 953.216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 119 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 960.96972
# Injection end time (seconds) = 961.224609375
# ----------------------------------------------
#
# ****** WARNING: At sample 120 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 968.96630203125
# Injection end time (seconds) = 969.21826171875
# ----------------------------------------------
#
# ****** WARNING: At sample 121 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 976.96972
# Injection end time (seconds) = 977.22314453125
# ----------------------------------------------
#
# ****** WARNING: At sample 122 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 984.96972
# Injection end time (seconds) = 985.227294921875
# ----------------------------------------------
#
# ****** WARNING: At sample 123 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 992.95800125
# Injection end time (seconds) = 993.214111328125
# ----------------------------------------------
#
# ****** WARNING: At sample 124 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1000.96972
# Injection end time (seconds) = 1001.225830078125
# ----------------------------------------------
#
# ****** WARNING: At sample 125 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1008.96972
# Injection end time (seconds) = 1009.224853515625
# ----------------------------------------------
#
# ****** WARNING: At sample 126 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1016.96972
# Injection end time (seconds) = 1017.226806640625
# ----------------------------------------------
#
# ****** WARNING: At sample 127 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1024.95067703125
# Injection end time (seconds) = 1025.21044921875
# ----------------------------------------------
#
# ****** WARNING: At sample 128 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1032.96972
# Injection end time (seconds) = 1033.223876953125
# ----------------------------------------------
#
# ****** WARNING: At sample 129 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1040.9511653125
# Injection end time (seconds) = 1041.210693359375
# ----------------------------------------------
#
# ****** WARNING: At sample 130 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1048.954095
# Injection end time (seconds) = 1049.212158203125
# ----------------------------------------------
#
# ****** WARNING: At sample 131 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1056.96972
# Injection end time (seconds) = 1057.224853515625
# ----------------------------------------------
#
# ****** WARNING: At sample 132 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1064.9648371875
# Injection end time (seconds) = 1065.217529296875
# ----------------------------------------------
#
# ****** WARNING: At sample 133 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1072.954095
# Injection end time (seconds) = 1073.212158203125
# ----------------------------------------------
#
# ****** WARNING: At sample 134 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1080.96972
# Injection end time (seconds) = 1081.223388671875
# ----------------------------------------------
#
# ****** WARNING: At sample 135 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1088.96972
# Injection end time (seconds) = 1089.224853515625
# ----------------------------------------------
#
# ****** WARNING: At sample 136 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1096.96434890625
# Injection end time (seconds) = 1097.21728515625
# ----------------------------------------------
#
# ****** WARNING: At sample 137 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1104.96972
# Injection end time (seconds) = 1105.22119140625
# ----------------------------------------------
#
# ****** WARNING: At sample 138 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1112.96972
# Injection end time (seconds) = 1113.225830078125
# ----------------------------------------------
#
# ****** WARNING: At sample 139 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1120.9667903125
# Injection end time (seconds) = 1121.218505859375
# ----------------------------------------------
#
# ****** WARNING: At sample 140 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1128.96972
# Injection end time (seconds) = 1129.227294921875
# ----------------------------------------------
#
# ****** WARNING: At sample 141 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1136.96972
# Injection end time (seconds) = 1137.2216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 142 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1144.96972
# Injection end time (seconds) = 1145.223876953125
# ----------------------------------------------
#
# ****** WARNING: At sample 143 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1152.967766875
# Injection end time (seconds) = 1153.218994140625
# ----------------------------------------------
#
# ****** WARNING: At sample 144 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1160.96337234375
# Injection end time (seconds) = 1161.216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 145 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1168.96972
# Injection end time (seconds) = 1169.229736328125
# ----------------------------------------------
#
# ****** WARNING: At sample 146 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1176.956048125
# Injection end time (seconds) = 1177.213134765625
# ----------------------------------------------
#
# ****** WARNING: At sample 147 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1184.96972
# Injection end time (seconds) = 1185.2216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 148 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1192.96972
# Injection end time (seconds) = 1193.223388671875
# ----------------------------------------------
#
# ****** WARNING: At sample 149 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1200.96044265625
# Injection end time (seconds) = 1201.21533203125
# ----------------------------------------------
#
# ****** WARNING: At sample 150 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1208.9628840625
# Injection end time (seconds) = 1209.216552734375
# ----------------------------------------------
#
# ****** WARNING: At sample 151 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1216.96972
# Injection end time (seconds) = 1217.2294921875
# ----------------------------------------------
#
# ****** WARNING: At sample 152 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1224.96972
# Injection end time (seconds) = 1225.22021484375
# ----------------------------------------------
#
# ****** WARNING: At sample 153 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1232.96630203125
# Injection end time (seconds) = 1233.21826171875
# ----------------------------------------------
#
# ****** WARNING: At sample 154 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1240.96972
# Injection end time (seconds) = 1241.2216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 155 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1248.96972
# Injection end time (seconds) = 1249.224853515625
# ----------------------------------------------
#
# ****** WARNING: At sample 156 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1256.96434890625
# Injection end time (seconds) = 1257.21728515625
# ----------------------------------------------
#
# ****** WARNING: At sample 157 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1264.96972
# Injection end time (seconds) = 1265.220458984375
# ----------------------------------------------
#
# ****** WARNING: At sample 158 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1272.9628840625
# Injection end time (seconds) = 1273.216552734375
# ----------------------------------------------
#
# ****** WARNING: At sample 159 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1280.96972
# Injection end time (seconds) = 1281.22509765625
# ----------------------------------------------
#
# ****** WARNING: At sample 160 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1288.96972
# Injection end time (seconds) = 1289.225830078125
# ----------------------------------------------
#
# ****** WARNING: At sample 161 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1296.96972
# Injection end time (seconds) = 1297.2265625
# ----------------------------------------------
#
# ****** WARNING: At sample 162 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1304.959954375
# Injection end time (seconds) = 1305.215087890625
# ----------------------------------------------
#
# ****** WARNING: At sample 163 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1312.96972
# Injection end time (seconds) = 1313.22216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 164 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1320.95946609375
# Injection end time (seconds) = 1321.21484375
# ----------------------------------------------
#
# ****** WARNING: At sample 165 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1328.96923171875
# Injection end time (seconds) = 1329.2197265625
# ----------------------------------------------
#
# ****** WARNING: At sample 166 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1336.96044265625
# Injection end time (seconds) = 1337.21533203125
# ----------------------------------------------
#
# ****** WARNING: At sample 167 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1344.96972
# Injection end time (seconds) = 1345.225830078125
# ----------------------------------------------
#
# ****** WARNING: At sample 168 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1352.96972
# Injection end time (seconds) = 1353.2265625
# ----------------------------------------------
#
#
# ****** WARNING: At sample 169 Injection's start is outside the window (LEFT)
# Window's initial time (seconds) = 1360.0
# Injection initial time (seconds) = 1360.0
# ----------------------------------------------
#
# ****** WARNING: At sample 170 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1368.96337234375
# Injection end time (seconds) = 1369.216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 171 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1376.95018875
# Injection end time (seconds) = 1377.210205078125
# ----------------------------------------------
#
# ****** WARNING: At sample 172 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1384.9550715625
# Injection end time (seconds) = 1385.212646484375
# ----------------------------------------------
#
# ****** WARNING: At sample 173 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1392.96972
# Injection end time (seconds) = 1393.22509765625
# ----------------------------------------------
#
# ****** WARNING: At sample 174 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1400.9589778125
# Injection end time (seconds) = 1401.214599609375
# ----------------------------------------------
#
# ****** WARNING: At sample 175 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1408.95360671875
# Injection end time (seconds) = 1409.2119140625
# ----------------------------------------------
#
# ****** WARNING: At sample 176 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1416.96825515625
# Injection end time (seconds) = 1417.21923828125
# ----------------------------------------------
#
# ****** WARNING: At sample 177 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1424.963860625
# Injection end time (seconds) = 1425.217041015625
# ----------------------------------------------
#
# ****** WARNING: At sample 178 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1432.963860625
# Injection end time (seconds) = 1433.217041015625
# ----------------------------------------------
#
# ****** WARNING: At sample 179 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1440.96727859375
# Injection end time (seconds) = 1441.21875
# ----------------------------------------------
#
# ****** WARNING: At sample 180 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1448.96972
# Injection end time (seconds) = 1449.223876953125
# ----------------------------------------------
#
# ****** WARNING: At sample 181 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1456.96972
# Injection end time (seconds) = 1457.22705078125
# ----------------------------------------------
#
# ****** WARNING: At sample 182 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1464.96044265625
# Injection end time (seconds) = 1465.21533203125
# ----------------------------------------------
#
# ****** WARNING: At sample 183 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1472.954095
# Injection end time (seconds) = 1473.212158203125
# ----------------------------------------------
#
# ****** WARNING: At sample 184 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1480.96141921875
# Injection end time (seconds) = 1481.2158203125
# ----------------------------------------------
#
# ****** WARNING: At sample 185 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1488.96972
# Injection end time (seconds) = 1489.2275390625
# ----------------------------------------------
#
# ****** WARNING: At sample 186 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1496.96972
# Injection end time (seconds) = 1497.2275390625
# ----------------------------------------------
#
# ****** WARNING: At sample 187 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1504.95263015625
# Injection end time (seconds) = 1505.21142578125
# ----------------------------------------------
#
# ****** WARNING: At sample 188 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1512.96972
# Injection end time (seconds) = 1513.226318359375
# ----------------------------------------------
#
# ****** WARNING: At sample 189 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1520.96972
# Injection end time (seconds) = 1521.2275390625
# ----------------------------------------------
#
# ****** WARNING: At sample 190 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1528.96972
# Injection end time (seconds) = 1529.222900390625
# ----------------------------------------------
#
# ****** WARNING: At sample 191 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1536.96581375
# Injection end time (seconds) = 1537.218017578125
# ----------------------------------------------
#
# ****** WARNING: At sample 192 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1544.96972
# Injection end time (seconds) = 1545.22412109375
# ----------------------------------------------
#
# ****** WARNING: At sample 193 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1552.963860625
# Injection end time (seconds) = 1553.217041015625
# ----------------------------------------------
#
# ****** WARNING: At sample 194 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1560.9511653125
# Injection end time (seconds) = 1561.210693359375
# ----------------------------------------------
#
# ****** WARNING: At sample 195 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1568.96972
# Injection end time (seconds) = 1569.224853515625
# ----------------------------------------------
#
# ****** WARNING: At sample 196 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1576.96825515625
# Injection end time (seconds) = 1577.21923828125
# ----------------------------------------------
#
# ****** WARNING: At sample 197 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1584.96972
# Injection end time (seconds) = 1585.228515625
# ----------------------------------------------
#
# ****** WARNING: At sample 198 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1592.956048125
# Injection end time (seconds) = 1593.213134765625
# ----------------------------------------------
#
# ****** WARNING: At sample 199 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1600.96532546875
# Injection end time (seconds) = 1601.2177734375
# ----------------------------------------------
#
# ****** WARNING: At sample 200 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1608.96630203125
# Injection end time (seconds) = 1609.21826171875
# ----------------------------------------------
#
# ****** WARNING: At sample 201 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1616.96972
# Injection end time (seconds) = 1617.221435546875
# ----------------------------------------------
#
# ****** WARNING: At sample 202 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1624.95458328125
# Injection end time (seconds) = 1625.21240234375
# ----------------------------------------------
#
# ****** WARNING: At sample 203 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1632.96972
# Injection end time (seconds) = 1633.224853515625
# ----------------------------------------------
#
# ****** WARNING: At sample 204 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1640.9667903125
# Injection end time (seconds) = 1641.218505859375
# ----------------------------------------------
#
# ****** WARNING: At sample 205 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1648.952141875
# Injection end time (seconds) = 1649.211181640625
# ----------------------------------------------
#
# ****** WARNING: At sample 206 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1656.96972
# Injection end time (seconds) = 1657.22802734375
# ----------------------------------------------
#
# ****** WARNING: At sample 207 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1664.96239578125
# Injection end time (seconds) = 1665.21630859375
# ----------------------------------------------
#
# ****** WARNING: At sample 208 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1672.9667903125
# Injection end time (seconds) = 1673.218505859375
# ----------------------------------------------
#
# ****** WARNING: At sample 209 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1680.96972
# Injection end time (seconds) = 1681.229736328125
# ----------------------------------------------
#
# ****** WARNING: At sample 210 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1688.967766875
# Injection end time (seconds) = 1689.218994140625
# ----------------------------------------------
#
# ****** WARNING: At sample 211 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1696.96972
# Injection end time (seconds) = 1697.221923828125
# ----------------------------------------------
#
# ****** WARNING: At sample 212 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1704.96972
# Injection end time (seconds) = 1705.224853515625
# ----------------------------------------------
#
# ****** WARNING: At sample 213 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1712.96972
# Injection end time (seconds) = 1713.228271484375
# ----------------------------------------------
#
# ****** WARNING: At sample 214 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1720.96972
# Injection end time (seconds) = 1721.222412109375
# ----------------------------------------------
#
# ****** WARNING: At sample 215 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1728.96972
# Injection end time (seconds) = 1729.222900390625
# ----------------------------------------------
#
# ****** WARNING: At sample 216 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1736.96972
# Injection end time (seconds) = 1737.2236328125
# ----------------------------------------------
#
# ****** WARNING: At sample 217 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1744.96972
# Injection end time (seconds) = 1745.220458984375
# ----------------------------------------------
#
# ****** WARNING: At sample 218 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1752.95848953125
# Injection end time (seconds) = 1753.21435546875
# ----------------------------------------------
#
# ****** WARNING: At sample 219 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1760.96972
# Injection end time (seconds) = 1761.22119140625
# ----------------------------------------------
#
#
# ****** WARNING: At sample 220 Injection's start is outside the window (LEFT)
# Window's initial time (seconds) = 1768.0
# Injection initial time (seconds) = 1768.0
# ----------------------------------------------
#
# ****** WARNING: At sample 221 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1776.9648371875
# Injection end time (seconds) = 1777.217529296875
# ----------------------------------------------
#
# ****** WARNING: At sample 222 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1784.96972
# Injection end time (seconds) = 1785.224365234375
# ----------------------------------------------
#
# ****** WARNING: At sample 223 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 1792.9570246875
# Injection end time (seconds) = 1793.213623046875
# ...
#
# ****** WARNING: At sample 437 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3504.956048125
# Injection end time (seconds) = 3505.213134765625
# ----------------------------------------------
#
# ****** WARNING: At sample 438 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3512.9648371875
# Injection end time (seconds) = 3513.217529296875
# ----------------------------------------------
#
# ****** WARNING: At sample 439 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3520.95555984375
# Injection end time (seconds) = 3521.212890625
# ----------------------------------------------
#
# ****** WARNING: At sample 440 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3528.96141921875
# Injection end time (seconds) = 3529.2158203125
# ----------------------------------------------
#
# ****** WARNING: At sample 441 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3536.96972
# Injection end time (seconds) = 3537.222412109375
# ----------------------------------------------
#
# ****** WARNING: At sample 442 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3544.9511653125
# Injection end time (seconds) = 3545.210693359375
# ----------------------------------------------
#
# ****** WARNING: At sample 443 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3552.96972
# Injection end time (seconds) = 3553.227783203125
# ----------------------------------------------
#
# ****** WARNING: At sample 444 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3560.95360671875
# Injection end time (seconds) = 3561.2119140625
# ----------------------------------------------
#
# ****** WARNING: At sample 445 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3568.956048125
# Injection end time (seconds) = 3569.213134765625
# ----------------------------------------------
#
# ****** WARNING: At sample 446 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3576.95067703125
# Injection end time (seconds) = 3577.21044921875
# ----------------------------------------------
#
# ****** WARNING: At sample 447 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3584.96972
# Injection end time (seconds) = 3585.220703125
# ----------------------------------------------
#
# ****** WARNING: At sample 448 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3592.96972
# Injection end time (seconds) = 3593.2236328125
# ----------------------------------------------
#
# ****** WARNING: At sample 449 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3600.96630203125
# Injection end time (seconds) = 3601.21826171875
# ----------------------------------------------
#
# ****** WARNING: At sample 450 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3608.96972
# Injection end time (seconds) = 3609.22802734375
# ----------------------------------------------
#
# ****** WARNING: At sample 451 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3616.96972
# Injection end time (seconds) = 3617.22265625
# ----------------------------------------------
#
# ****** WARNING: At sample 452 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3624.96630203125
# Injection end time (seconds) = 3625.21826171875
# ----------------------------------------------
#
# ****** WARNING: At sample 453 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3632.96972
# Injection end time (seconds) = 3633.22802734375
# ----------------------------------------------
#
# ****** WARNING: At sample 454 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3640.96972
# Injection end time (seconds) = 3641.228759765625
# ----------------------------------------------
#
# ****** WARNING: At sample 455 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3648.96923171875
# Injection end time (seconds) = 3649.2197265625
# ----------------------------------------------
#
# ****** WARNING: At sample 456 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3656.96923171875
# Injection end time (seconds) = 3657.2197265625
# ----------------------------------------------
#
# ****** WARNING: At sample 457 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3664.952141875
# Injection end time (seconds) = 3665.211181640625
# ----------------------------------------------
#
# ****** WARNING: At sample 458 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3672.96972
# Injection end time (seconds) = 3673.228515625
# ----------------------------------------------
#
# ****** WARNING: At sample 459 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3680.96972
# Injection end time (seconds) = 3681.2265625
# ----------------------------------------------
#
# ****** WARNING: At sample 460 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3688.9687434375
# Injection end time (seconds) = 3689.219482421875
# ----------------------------------------------
#
# ****** WARNING: At sample 461 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3696.9687434375
# Injection end time (seconds) = 3697.219482421875
# ----------------------------------------------
#
# ****** WARNING: At sample 462 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3704.9570246875
# Injection end time (seconds) = 3705.213623046875
# ----------------------------------------------
#
# ****** WARNING: At sample 463 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3712.96727859375
# Injection end time (seconds) = 3713.21875
# ----------------------------------------------
#
# ****** WARNING: At sample 464 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3720.95848953125
# Injection end time (seconds) = 3721.21435546875
# ----------------------------------------------
#
# ****** WARNING: At sample 465 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3728.96972
# Injection end time (seconds) = 3729.225341796875
# ----------------------------------------------
#
# ****** WARNING: At sample 466 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3736.96972
# Injection end time (seconds) = 3737.22705078125
# ----------------------------------------------
#
# ****** WARNING: At sample 467 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3744.956048125
# Injection end time (seconds) = 3745.213134765625
# ----------------------------------------------
#
# ****** WARNING: At sample 468 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3752.96972
# Injection end time (seconds) = 3753.228271484375
# ----------------------------------------------
#
# ****** WARNING: At sample 469 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3760.95751296875
# Injection end time (seconds) = 3761.2138671875
# ----------------------------------------------
#
# ****** WARNING: At sample 470 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3768.96972
# Injection end time (seconds) = 3769.22021484375
# ----------------------------------------------
#
# ****** WARNING: At sample 471 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3776.96972
# Injection end time (seconds) = 3777.22607421875
# ----------------------------------------------
#
# ****** WARNING: At sample 472 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3784.96141921875
# Injection end time (seconds) = 3785.2158203125
# ----------------------------------------------
#
# ****** WARNING: At sample 473 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3792.96727859375
# Injection end time (seconds) = 3793.21875
# ----------------------------------------------
#
# ****** WARNING: At sample 474 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3800.95653640625
# Injection end time (seconds) = 3801.21337890625
# ----------------------------------------------
#
# ****** WARNING: At sample 475 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3808.96923171875
# Injection end time (seconds) = 3809.2197265625
# ----------------------------------------------
#
# ****** WARNING: At sample 476 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3816.9589778125
# Injection end time (seconds) = 3817.214599609375
# ----------------------------------------------
#
# ****** WARNING: At sample 477 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3824.95653640625
# Injection end time (seconds) = 3825.21337890625
# ----------------------------------------------
#
# ****** WARNING: At sample 478 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3832.96044265625
# Injection end time (seconds) = 3833.21533203125
# ----------------------------------------------
#
# ****** WARNING: At sample 479 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3840.96972
# Injection end time (seconds) = 3841.22265625
# ----------------------------------------------
#
# ****** WARNING: At sample 480 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3848.96581375
# Injection end time (seconds) = 3849.218017578125
# ----------------------------------------------
#
# ****** WARNING: At sample 481 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3856.96532546875
# Injection end time (seconds) = 3857.2177734375
# ----------------------------------------------
#
# ****** WARNING: At sample 482 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3864.9570246875
# Injection end time (seconds) = 3865.213623046875
# ----------------------------------------------
#
# ****** WARNING: At sample 483 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3872.96972
# Injection end time (seconds) = 3873.22265625
# ----------------------------------------------
#
# ****** WARNING: At sample 484 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3880.96972
# Injection end time (seconds) = 3881.227294921875
# ----------------------------------------------
#
# ****** WARNING: At sample 485 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3888.96972
# Injection end time (seconds) = 3889.224609375
# ----------------------------------------------
#
# ****** WARNING: At sample 486 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3896.96972
# Injection end time (seconds) = 3897.2236328125
# ----------------------------------------------
#
# ****** WARNING: At sample 487 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3904.96972
# Injection end time (seconds) = 3905.22802734375
# ----------------------------------------------
#
# ****** WARNING: At sample 488 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3912.96972
# Injection end time (seconds) = 3913.225341796875
# ----------------------------------------------
#
# ****** WARNING: At sample 489 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3920.95555984375
# Injection end time (seconds) = 3921.212890625
# ----------------------------------------------
#
# ****** WARNING: At sample 490 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3928.9550715625
# Injection end time (seconds) = 3929.212646484375
# ----------------------------------------------
#
# ****** WARNING: At sample 491 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3936.9687434375
# Injection end time (seconds) = 3937.219482421875
# ----------------------------------------------
#
# ****** WARNING: At sample 492 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3944.96923171875
# Injection end time (seconds) = 3945.2197265625
# ----------------------------------------------
#
# ****** WARNING: At sample 493 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3952.967766875
# Injection end time (seconds) = 3953.218994140625
# ----------------------------------------------
#
# ****** WARNING: At sample 494 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3960.9628840625
# Injection end time (seconds) = 3961.216552734375
# ----------------------------------------------
#
# ****** WARNING: At sample 495 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3968.96972
# Injection end time (seconds) = 3969.22607421875
# ----------------------------------------------
#
# ****** WARNING: At sample 496 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3976.963860625
# Injection end time (seconds) = 3977.217041015625
# ----------------------------------------------
#
# ****** WARNING: At sample 497 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3984.96337234375
# Injection end time (seconds) = 3985.216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 498 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 3992.9550715625
# Injection end time (seconds) = 3993.212646484375
# ----------------------------------------------
#
# ****** WARNING: At sample 499 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4000.96972
# Injection end time (seconds) = 4001.22314453125
# ----------------------------------------------
#
# ****** WARNING: At sample 500 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4008.96972
# Injection end time (seconds) = 4009.220458984375
# ----------------------------------------------
#
# ****** WARNING: At sample 501 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4016.96972
# Injection end time (seconds) = 4017.226318359375
# ----------------------------------------------
#
# ****** WARNING: At sample 502 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4024.96972
# Injection end time (seconds) = 4025.22119140625
# ----------------------------------------------
#
# ****** WARNING: At sample 503 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4032.96972
# Injection end time (seconds) = 4033.224609375
# ----------------------------------------------
#
# ****** WARNING: At sample 504 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4040.96972
# Injection end time (seconds) = 4041.2255859375
# ----------------------------------------------
#
# ****** WARNING: At sample 505 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4048.954095
# Injection end time (seconds) = 4049.212158203125
# ----------------------------------------------
#
# ****** WARNING: At sample 506 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4056.96972
# Injection end time (seconds) = 4057.22119140625
# ----------------------------------------------
#
# ****** WARNING: At sample 507 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4064.96825515625
# Injection end time (seconds) = 4065.21923828125
# ----------------------------------------------
#
# ****** WARNING: At sample 508 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4072.96337234375
# Injection end time (seconds) = 4073.216796875
# ----------------------------------------------
#
# ****** WARNING: At sample 509 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4080.95848953125
# Injection end time (seconds) = 4081.21435546875
# ----------------------------------------------
#
# ****** WARNING: At sample 510 Injection's end is outside the window (RIGHT)
# Window's end time (seconds) = 4088.96972
# Injection end time (seconds) = 4089.228759765625
# ----------------------------------------------

# %%
# ------> Recover information useful to save data

# Noise segment GPS time

result = re.search("_noise_", F_noi[nfile_i])
i_ini = result.span()[0]+10
result = re.search(".txt", F_noi[nfile_i])
i_end = result.span()[0]

gps = F_noi[nfile_i][i_ini:i_end]

# Distance from the source

result = re.search("_D_", F_wav[wfile_i])
i_ini = result.span()[0]+3
result = re.search("Kpc_", F_wav[wfile_i])
i_end = result.span()[0]

distance = F_wav[wfile_i][i_ini:i_end]

# Class of the injected waveform

result = re.search("_class_", F_wav[wfile_i])
i_ini = result.span()[0]+7
result = re.search(".txt", F_wav[wfile_i])
i_end = result.span()[0]

wf_class = F_wav[wfile_i][i_ini:i_end]

# %%
# ------> Set directory to save dataset

save_dir = '/home/manuel/Research Projects/GW Data analysis/GitHub/CCSNeHFGW_ResNetClass/Datasets/NumWf/'

datasets_dir = save_dir + detector + "_" + gps + "/wfclass_" + wf_class + "/" + wf_model 

if not os.path.exists(datasets_dir):
    os.makedirs(datasets_dir)
else:
    pass

# %% [markdown]
# ### 4.3. Window samples generation

# %%
doplots_samples = set_doplots # CHECK, plot samples (time domain | TF representation)

# ------> Generate window samples

# Sampling frequency
ts = t[1] - t[0]
fs = 1 / ts

# Window for spectrograms
wnd="hamming"

# Initialize list of windows
all_windows = []

# Initialize list for updated log file
log_data = []

# FIRST LOOP, j index: window count variable
# --------------------------------------------

for j in range(len(t_inj)): # Extract all windows along the strain segment

    print("Window sample No.", j)
    print("----------------------")
    
    window = np.zeros(int(fs*Twin))

    # SECOND LOOP, k index: Window samples count variable
    # --------------------------------------------------------
    
    for k in range(len(window)):
        
        # Extract strain data along the window
        window[k] = s[locate_win[j]+k]
    
    all_windows.append(window)
    
    print("Waveform SNR: ", wf_SNR[j])
    print("Injection location (seconds): ", t_inj[j])
    print("")
    print("Waveform duration (seconds): ", wf_duration[j])
    print("")
    print("Window initial time (seconds): ", t[locate_win[j]])
    print("Window end time (seconds): ", t[locate_win[j]+k])
    #print("Window length (in seconds):", t[locate_win[j]+k]-t[locate_win[j]])
    print("Extracted ", k, " data points")
    
    # CHECK: To ensure injection location is inside window sample
    
    if t_inj[j] < t[locate_win[j]]:
        print("!!!!!!!!!!!!!!!!! ERROR : t_injection is before the sample window")
    
    elif j < len(t_inj)-1:
        if t_inj[j] > t[locate_win[j+1]]:
            print("!!!!!!!!!!!!!!!!! ERROR : t_injection is after the sample window ")
    
    print("")
    
    # Select window samples belonging in a specific SNR range
    # ----------------------------------------------------------
    
    if wf_SNR[j] <= SNR_max:
        if wf_SNR[j] >= SNR_min:
        
            if doplots_samples:
            
                # Plot the window sample (strain)
                # ---------------------------------
            
                plt.figure(1, figsize=(6,4))
        
                #plt.plot(np.arange(0, Twin, ts), all_windows[num_win], label='Strain')
                plt.plot(t[locate_win[j]:locate_win[j]+len(window)], all_windows[j], label='Strain')
                #plt.title("Sample", fontsize=15)
                plt.xlabel('Time [sec]', fontsize=14)
                plt.ylabel('strain', fontsize=14)
                plt.grid()
                plt.legend()
                plt.tight_layout()
                plt.show()
                plt.figure(1).clear()
                gc.collect()
    
                # Plot the window sample (TF representation)
                # --------------------------------------
    
                #freq, time, Sxx = signal.spectrogram(all_windows[j], fs, window=wnd, nperseg=256)
                time, freq, Sxx = WaveletTF_transform(all_windows[j], fs, 10, 2000, 10, 7, 0)
    
                plt.figure(2, figsize=(6.5,5))
                plt.pcolormesh(time+t[locate_win[j]], freq, Sxx, shading='gouraud')
                plt.ylabel('Frequency [Hz]', fontsize=14)
                plt.xlabel('Time [sec]', fontsize=14)
                plt.show()
        
                plt.figure(2).clear()
                gc.collect()
            
            # Save information in log_data list
            #log_data.append([t_inj[j], jitter[j], wf_SNR[j], Slope[j], f_ini[j], f_end[j], wf_duration[j]])
            log_data.append([t_inj[j], jitter[j], wf_SNR[j], wf_duration[j]])
    
            # Save window samples
            sample_number = str(j).zfill(6)
            df_strain = pd.DataFrame({"time (seconds)" : t[locate_win[j]:locate_win[j]+len(window)], "strain" : all_windows[j]})
            df_strain.to_csv(datasets_dir + "/sample_strain_" + sample_number + ".txt", index=False)
 
            print("****************************************************************")
            print("")
# Out:
# Window sample No. 0
# ----------------------
# Waveform SNR:  82.59198275914237
# Injection location (seconds):  8.00341796875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  8.0
# Window end time (seconds):  8.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 1
# ----------------------
# Waveform SNR:  80.55253231458876
# Injection location (seconds):  16.009521484375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  16.0
# Window end time (seconds):  16.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 2
# ----------------------
# Waveform SNR:  80.360319973659
# Injection location (seconds):  24.000244140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  24.0
# Window end time (seconds):  24.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 3
# ----------------------
# Waveform SNR:  80.82735261877362
# Injection location (seconds):  32.002685546875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  32.0
# Window end time (seconds):  32.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 4
# ----------------------
# Waveform SNR:  80.34326813640489
# Injection location (seconds):  39.993896484375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  39.98779296875
# Window end time (seconds):  40.95703125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 5
# ----------------------
# Waveform SNR:  82.56199048940366
# Injection location (seconds):  48.005126953125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  48.0
# Window end time (seconds):  48.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 6
# ----------------------
# Waveform SNR:  81.24965193524923
# Injection location (seconds):  55.997314453125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  55.99462890625
# Window end time (seconds):  56.9638671875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 7
# ----------------------
# Waveform SNR:  81.3299665673607
# Injection location (seconds):  64.00244140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  64.0
# Window end time (seconds):  64.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 8
# ----------------------
# Waveform SNR:  80.69120190377835
# Injection location (seconds):  72.0087890625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  72.0
# Window end time (seconds):  72.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 9
# ----------------------
# Waveform SNR:  81.7555940071533
# Injection location (seconds):  79.9990234375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  79.998046875
# Window end time (seconds):  80.96728515625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 10
# ----------------------
# Waveform SNR:  81.34239710706542
# Injection location (seconds):  87.99609375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  87.9921875
# Window end time (seconds):  88.96142578125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 11
# ----------------------
# Waveform SNR:  84.18651242533277
# Injection location (seconds):  95.993896484375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  95.98779296875
# Window end time (seconds):  96.95703125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 12
# ----------------------
# Waveform SNR:  82.78056218840082
# Injection location (seconds):  104.001220703125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  104.0
# Window end time (seconds):  104.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 13
# ----------------------
# Waveform SNR:  80.87953369474559
# Injection location (seconds):  111.994384765625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  111.98876953125
# Window end time (seconds):  112.9580078125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 14
# ----------------------
# Waveform SNR:  80.54589031541099
# Injection location (seconds):  120.008056640625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  120.0
# Window end time (seconds):  120.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 15
# ----------------------
# Waveform SNR:  81.47769155831936
# Injection location (seconds):  127.997314453125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  127.99462890625
# Window end time (seconds):  128.9638671875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 16
# ----------------------
# Waveform SNR:  81.86177055424413
# Injection location (seconds):  136.007080078125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  136.0
# Window end time (seconds):  136.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 17
# ----------------------
# Waveform SNR:  80.60345976703893
# Injection location (seconds):  144.0029296875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  144.0
# Window end time (seconds):  144.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 18
# ----------------------
# Waveform SNR:  84.13968678755607
# Injection location (seconds):  151.996337890625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  151.99267578125
# Window end time (seconds):  152.9619140625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 19
# ----------------------
# Waveform SNR:  81.4822983186662
# Injection location (seconds):  159.992919921875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  159.98583984375
# Window end time (seconds):  160.955078125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 20
# ----------------------
# Waveform SNR:  80.82438287558792
# Injection location (seconds):  167.991455078125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  167.98291015625
# Window end time (seconds):  168.9521484375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 21
# ----------------------
# Waveform SNR:  80.21631209063497
# Injection location (seconds):  176.004150390625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  176.0
# Window end time (seconds):  176.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 22
# ----------------------
# Waveform SNR:  80.5183175772041
# Injection location (seconds):  184.007080078125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  184.0
# Window end time (seconds):  184.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 23
# ----------------------
# Waveform SNR:  84.6338923581969
# Injection location (seconds):  192.00244140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  192.0
# Window end time (seconds):  192.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 24
# ----------------------
# Waveform SNR:  80.87125861041815
# Injection location (seconds):  200.002197265625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  200.0
# Window end time (seconds):  200.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 25
# ----------------------
# Waveform SNR:  80.94002137880435
# Injection location (seconds):  207.99365234375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  207.9873046875
# Window end time (seconds):  208.95654296875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 26
# ----------------------
# Waveform SNR:  80.90869403495027
# Injection location (seconds):  216.001708984375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  216.0
# Window end time (seconds):  216.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 27
# ----------------------
# Waveform SNR:  80.78033695593727
# Injection location (seconds):  224.00341796875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  224.0
# Window end time (seconds):  224.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 28
# ----------------------
# Waveform SNR:  79.79420479190902
# Injection location (seconds):  231.99462890625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  231.9892578125
# Window end time (seconds):  232.95849609375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 29
# ----------------------
# Waveform SNR:  81.94947840986026
# Injection location (seconds):  239.998046875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  239.99609375
# Window end time (seconds):  240.96533203125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 30
# ----------------------
# Waveform SNR:  80.58427961915689
# Injection location (seconds):  247.998779296875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  247.99755859375
# Window end time (seconds):  248.966796875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 31
# ----------------------
# Waveform SNR:  81.81808261205295
# Injection location (seconds):  255.9931640625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  255.986328125
# Window end time (seconds):  256.95556640625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 32
# ----------------------
# Waveform SNR:  80.52933582292412
# Injection location (seconds):  264.009033203125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  264.0
# Window end time (seconds):  264.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 33
# ----------------------
# Waveform SNR:  79.99887081897879
# Injection location (seconds):  271.99462890625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  271.9892578125
# Window end time (seconds):  272.95849609375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 34
# ----------------------
# Waveform SNR:  81.42443382360429
# Injection location (seconds):  279.9931640625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  279.986328125
# Window end time (seconds):  280.95556640625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 35
# ----------------------
# Waveform SNR:  81.50653629205435
# Injection location (seconds):  287.999267578125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  287.99853515625
# Window end time (seconds):  288.9677734375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 36
# ----------------------
# Waveform SNR:  81.96769706025339
# Injection location (seconds):  295.99072265625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  295.9814453125
# Window end time (seconds):  296.95068359375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 37
# ----------------------
# Waveform SNR:  82.14623311682809
# Injection location (seconds):  303.99853515625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  303.9970703125
# Window end time (seconds):  304.96630859375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 38
# ----------------------
# Waveform SNR:  81.06711018278313
# Injection location (seconds):  312.00146484375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  312.0
# Window end time (seconds):  312.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 39
# ----------------------
# Waveform SNR:  80.77183745129368
# Injection location (seconds):  319.990234375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  319.98046875
# Window end time (seconds):  320.94970703125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 40
# ----------------------
# Waveform SNR:  80.65498937477392
# Injection location (seconds):  327.998291015625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  327.99658203125
# Window end time (seconds):  328.9658203125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 41
# ----------------------
# Waveform SNR:  80.95964693351358
# Injection location (seconds):  336.005126953125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  336.0
# Window end time (seconds):  336.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 42
# ----------------------
# Waveform SNR:  80.10520582777635
# Injection location (seconds):  343.992431640625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  343.98486328125
# Window end time (seconds):  344.9541015625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 43
# ----------------------
# Waveform SNR:  80.64031597581638
# Injection location (seconds):  351.9990234375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  351.998046875
# Window end time (seconds):  352.96728515625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 44
# ----------------------
# Waveform SNR:  82.12036783089697
# Injection location (seconds):  360.005126953125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  360.0
# Window end time (seconds):  360.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 45
# ----------------------
# Waveform SNR:  80.1976253384002
# Injection location (seconds):  367.9951171875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  367.990234375
# Window end time (seconds):  368.95947265625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 46
# ----------------------
# Waveform SNR:  83.30980310257416
# Injection location (seconds):  376.006591796875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  376.0
# Window end time (seconds):  376.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 47
# ----------------------
# Waveform SNR:  80.040746925304
# Injection location (seconds):  383.990478515625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  383.98095703125
# Window end time (seconds):  384.9501953125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 48
# ----------------------
# Waveform SNR:  80.39315157252996
# Injection location (seconds):  392.0078125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  392.0
# Window end time (seconds):  392.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 49
# ----------------------
# Waveform SNR:  81.79691606722864
# Injection location (seconds):  400.006591796875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  400.0
# Window end time (seconds):  400.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 50
# ----------------------
# Waveform SNR:  83.43147109195256
# Injection location (seconds):  408.009765625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  408.0
# Window end time (seconds):  408.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 51
# ----------------------
# Waveform SNR:  84.71904185065995
# Injection location (seconds):  415.9951171875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  415.990234375
# Window end time (seconds):  416.95947265625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 52
# ----------------------
# Waveform SNR:  80.68820065172535
# Injection location (seconds):  423.99853515625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  423.9970703125
# Window end time (seconds):  424.96630859375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 53
# ----------------------
# Waveform SNR:  81.10853781003541
# Injection location (seconds):  431.9921875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  431.984375
# Window end time (seconds):  432.95361328125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 54
# ----------------------
# Waveform SNR:  80.97280940188934
# Injection location (seconds):  440.005126953125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  440.0
# Window end time (seconds):  440.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 55
# ----------------------
# Waveform SNR:  81.94093470435148
# Injection location (seconds):  447.9970703125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  447.994140625
# Window end time (seconds):  448.96337890625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 56
# ----------------------
# Waveform SNR:  83.11620296865414
# Injection location (seconds):  456.001220703125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  456.0
# Window end time (seconds):  456.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 57
# ----------------------
# Waveform SNR:  80.42590632108062
# Injection location (seconds):  464.007568359375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  464.0
# Window end time (seconds):  464.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 58
# ----------------------
# Waveform SNR:  81.36245409178706
# Injection location (seconds):  471.99755859375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  471.9951171875
# Window end time (seconds):  472.96435546875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 59
# ----------------------
# Waveform SNR:  81.54703403977449
# Injection location (seconds):  480.008544921875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  480.0
# Window end time (seconds):  480.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 60
# ----------------------
# Waveform SNR:  81.06414045506237
# Injection location (seconds):  487.994140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  487.98828125
# Window end time (seconds):  488.95751953125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 61
# ----------------------
# Waveform SNR:  83.96115453663916
# Injection location (seconds):  496.000732421875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  496.0
# Window end time (seconds):  496.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 62
# ----------------------
# Waveform SNR:  79.25032990870609
# Injection location (seconds):  503.99853515625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  503.9970703125
# Window end time (seconds):  504.96630859375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 63
# ----------------------
# Waveform SNR:  82.30019794124489
# Injection location (seconds):  511.998779296875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  511.99755859375
# Window end time (seconds):  512.966796875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 64
# ----------------------
# Waveform SNR:  81.42594489609597
# Injection location (seconds):  520.00244140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  520.0
# Window end time (seconds):  520.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 65
# ----------------------
# Waveform SNR:  82.75598417169286
# Injection location (seconds):  528.0048828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  528.0
# Window end time (seconds):  528.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 66
# ----------------------
# Waveform SNR:  81.50006436340988
# Injection location (seconds):  536.004150390625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  536.0
# Window end time (seconds):  536.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 67
# ----------------------
# Waveform SNR:  82.14048610563157
# Injection location (seconds):  543.992919921875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  543.98583984375
# Window end time (seconds):  544.955078125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 68
# ----------------------
# Waveform SNR:  80.31585722854044
# Injection location (seconds):  552.006103515625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  552.0
# Window end time (seconds):  552.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 69
# ----------------------
# Waveform SNR:  79.68166038228959
# Injection location (seconds):  559.99755859375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  559.9951171875
# Window end time (seconds):  560.96435546875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 70
# ----------------------
# Waveform SNR:  79.81949350567731
# Injection location (seconds):  567.9951171875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  567.990234375
# Window end time (seconds):  568.95947265625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 71
# ----------------------
# Waveform SNR:  84.85141749118463
# Injection location (seconds):  575.999755859375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  575.99951171875
# Window end time (seconds):  576.96875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 72
# ----------------------
# Waveform SNR:  81.13093316713305
# Injection location (seconds):  583.997314453125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  583.99462890625
# Window end time (seconds):  584.9638671875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 73
# ----------------------
# Waveform SNR:  81.64051435096052
# Injection location (seconds):  591.998291015625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  591.99658203125
# Window end time (seconds):  592.9658203125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 74
# ----------------------
# Waveform SNR:  86.41857214317629
# Injection location (seconds):  599.9931640625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  599.986328125
# Window end time (seconds):  600.95556640625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 75
# ----------------------
# Waveform SNR:  80.43636703973124
# Injection location (seconds):  608.005126953125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  608.0
# Window end time (seconds):  608.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 76
# ----------------------
# Waveform SNR:  81.08686972821876
# Injection location (seconds):  616.0048828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  616.0
# Window end time (seconds):  616.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 77
# ----------------------
# Waveform SNR:  80.50040406505963
# Injection location (seconds):  624.003173828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  624.0
# Window end time (seconds):  624.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 78
# ----------------------
# Waveform SNR:  82.05688278632562
# Injection location (seconds):  632.0
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  632.0
# Window end time (seconds):  632.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 79
# ----------------------
# Waveform SNR:  82.26393362427926
# Injection location (seconds):  640.00048828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  640.0
# Window end time (seconds):  640.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 80
# ----------------------
# Waveform SNR:  80.00594812719564
# Injection location (seconds):  647.994140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  647.98828125
# Window end time (seconds):  648.95751953125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 81
# ----------------------
# Waveform SNR:  82.04498452854749
# Injection location (seconds):  655.994140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  655.98828125
# Window end time (seconds):  656.95751953125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 82
# ----------------------
# Waveform SNR:  80.98419154337559
# Injection location (seconds):  663.996337890625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  663.99267578125
# Window end time (seconds):  664.9619140625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 83
# ----------------------
# Waveform SNR:  83.65165304969109
# Injection location (seconds):  671.994140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  671.98828125
# Window end time (seconds):  672.95751953125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 84
# ----------------------
# Waveform SNR:  80.35407737553477
# Injection location (seconds):  679.995849609375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  679.99169921875
# Window end time (seconds):  680.9609375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 85
# ----------------------
# Waveform SNR:  81.12735890646115
# Injection location (seconds):  688.00830078125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  688.0
# Window end time (seconds):  688.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 86
# ----------------------
# Waveform SNR:  81.64997789106343
# Injection location (seconds):  695.994140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  695.98828125
# Window end time (seconds):  696.95751953125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 87
# ----------------------
# Waveform SNR:  83.01057404635496
# Injection location (seconds):  703.99609375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  703.9921875
# Window end time (seconds):  704.96142578125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 88
# ----------------------
# Waveform SNR:  81.56326936061343
# Injection location (seconds):  712.00341796875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  712.0
# Window end time (seconds):  712.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 89
# ----------------------
# Waveform SNR:  80.94227309413706
# Injection location (seconds):  720.0068359375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  720.0
# Window end time (seconds):  720.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 90
# ----------------------
# Waveform SNR:  80.13532180414848
# Injection location (seconds):  728.00732421875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  728.0
# Window end time (seconds):  728.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 91
# ----------------------
# Waveform SNR:  81.0664629954145
# Injection location (seconds):  736.009033203125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  736.0
# Window end time (seconds):  736.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 92
# ----------------------
# Waveform SNR:  81.9591601339836
# Injection location (seconds):  743.998291015625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  743.99658203125
# Window end time (seconds):  744.9658203125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 93
# ----------------------
# Waveform SNR:  83.30186656873708
# Injection location (seconds):  751.99072265625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  751.9814453125
# Window end time (seconds):  752.95068359375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 94
# ----------------------
# Waveform SNR:  82.31610080479925
# Injection location (seconds):  759.993408203125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  759.98681640625
# Window end time (seconds):  760.9560546875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 95
# ----------------------
# Waveform SNR:  81.42365362433442
# Injection location (seconds):  767.9990234375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  767.998046875
# Window end time (seconds):  768.96728515625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 96
# ----------------------
# Waveform SNR:  81.4216587566955
# Injection location (seconds):  776.0078125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  776.0
# Window end time (seconds):  776.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 97
# ----------------------
# Waveform SNR:  80.84211510831639
# Injection location (seconds):  783.997314453125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  783.99462890625
# Window end time (seconds):  784.9638671875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 98
# ----------------------
# Waveform SNR:  81.47443216479736
# Injection location (seconds):  791.994873046875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  791.98974609375
# Window end time (seconds):  792.958984375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 99
# ----------------------
# Waveform SNR:  80.7986771728854
# Injection location (seconds):  800.00732421875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  800.0
# Window end time (seconds):  800.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 100
# ----------------------
# Waveform SNR:  85.84720640982272
# Injection location (seconds):  807.999755859375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  807.99951171875
# Window end time (seconds):  808.96875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 101
# ----------------------
# Waveform SNR:  80.84226699280256
# Injection location (seconds):  815.990234375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  815.98046875
# Window end time (seconds):  816.94970703125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 102
# ----------------------
# Waveform SNR:  84.28912221048884
# Injection location (seconds):  824.003662109375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  824.0
# Window end time (seconds):  824.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 103
# ----------------------
# Waveform SNR:  81.2594336220719
# Injection location (seconds):  832.0
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  832.0
# Window end time (seconds):  832.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 104
# ----------------------
# Waveform SNR:  80.45161855772709
# Injection location (seconds):  840.000244140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  840.0
# Window end time (seconds):  840.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 105
# ----------------------
# Waveform SNR:  81.06437880651661
# Injection location (seconds):  848.009521484375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  848.0
# Window end time (seconds):  848.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 106
# ----------------------
# Waveform SNR:  82.40039079133838
# Injection location (seconds):  855.996826171875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  855.99365234375
# Window end time (seconds):  856.962890625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 107
# ----------------------
# Waveform SNR:  80.3160158662835
# Injection location (seconds):  864.009033203125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  864.0
# Window end time (seconds):  864.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 108
# ----------------------
# Waveform SNR:  80.93932858751113
# Injection location (seconds):  872.00390625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  872.0
# Window end time (seconds):  872.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 109
# ----------------------
# Waveform SNR:  80.11672045748263
# Injection location (seconds):  879.991455078125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  879.98291015625
# Window end time (seconds):  880.9521484375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 110
# ----------------------
# Waveform SNR:  81.18021152094582
# Injection location (seconds):  888.004150390625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  888.0
# Window end time (seconds):  888.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 111
# ----------------------
# Waveform SNR:  81.48670856606518
# Injection location (seconds):  896.003173828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  896.0
# Window end time (seconds):  896.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 112
# ----------------------
# Waveform SNR:  80.55213820490698
# Injection location (seconds):  903.996826171875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  903.99365234375
# Window end time (seconds):  904.962890625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 113
# ----------------------
# Waveform SNR:  82.67694648193331
# Injection location (seconds):  911.992919921875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  911.98583984375
# Window end time (seconds):  912.955078125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 114
# ----------------------
# Waveform SNR:  80.17522615680106
# Injection location (seconds):  919.9970703125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  919.994140625
# Window end time (seconds):  920.96337890625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 115
# ----------------------
# Waveform SNR:  84.52714039830157
# Injection location (seconds):  928.0078125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  928.0
# Window end time (seconds):  928.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 116
# ----------------------
# Waveform SNR:  81.27081919818652
# Injection location (seconds):  936.005859375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  936.0
# Window end time (seconds):  936.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 117
# ----------------------
# Waveform SNR:  84.41618120303711
# Injection location (seconds):  944.008544921875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  944.0
# Window end time (seconds):  944.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 118
# ----------------------
# Waveform SNR:  83.18013393938229
# Injection location (seconds):  951.996826171875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  951.99365234375
# Window end time (seconds):  952.962890625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 119
# ----------------------
# Waveform SNR:  80.2924469880165
# Injection location (seconds):  960.004638671875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  960.0
# Window end time (seconds):  960.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 120
# ----------------------
# Waveform SNR:  79.46174411322313
# Injection location (seconds):  967.998291015625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  967.99658203125
# Window end time (seconds):  968.9658203125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 121
# ----------------------
# Waveform SNR:  80.47923706483657
# Injection location (seconds):  976.003173828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  976.0
# Window end time (seconds):  976.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 122
# ----------------------
# Waveform SNR:  80.84900141979766
# Injection location (seconds):  984.00732421875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  984.0
# Window end time (seconds):  984.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 123
# ----------------------
# Waveform SNR:  81.75674142191768
# Injection location (seconds):  991.994140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  991.98828125
# Window end time (seconds):  992.95751953125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 124
# ----------------------
# Waveform SNR:  80.14025400249487
# Injection location (seconds):  1000.005859375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1000.0
# Window end time (seconds):  1000.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 125
# ----------------------
# Waveform SNR:  80.43668839835293
# Injection location (seconds):  1008.0048828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1008.0
# Window end time (seconds):  1008.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 126
# ----------------------
# Waveform SNR:  83.50359049438909
# Injection location (seconds):  1016.0068359375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1016.0
# Window end time (seconds):  1016.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 127
# ----------------------
# Waveform SNR:  81.73776826385394
# Injection location (seconds):  1023.990478515625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1023.98095703125
# Window end time (seconds):  1024.9501953125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 128
# ----------------------
# Waveform SNR:  80.19117463530532
# Injection location (seconds):  1032.00390625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1032.0
# Window end time (seconds):  1032.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 129
# ----------------------
# Waveform SNR:  80.25130788824286
# Injection location (seconds):  1039.99072265625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1039.9814453125
# Window end time (seconds):  1040.95068359375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 130
# ----------------------
# Waveform SNR:  82.3401354344918
# Injection location (seconds):  1047.9921875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1047.984375
# Window end time (seconds):  1048.95361328125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 131
# ----------------------
# Waveform SNR:  82.34895811870778
# Injection location (seconds):  1056.0048828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1056.0
# Window end time (seconds):  1056.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 132
# ----------------------
# Waveform SNR:  81.39355659438304
# Injection location (seconds):  1063.99755859375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1063.9951171875
# Window end time (seconds):  1064.96435546875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 133
# ----------------------
# Waveform SNR:  81.74498506632855
# Injection location (seconds):  1071.9921875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1071.984375
# Window end time (seconds):  1072.95361328125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 134
# ----------------------
# Waveform SNR:  81.58827970732314
# Injection location (seconds):  1080.00341796875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1080.0
# Window end time (seconds):  1080.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 135
# ----------------------
# Waveform SNR:  80.89681016866328
# Injection location (seconds):  1088.0048828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  1088.0
# Window end time (seconds):  1088.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# ...
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3736.0
# Window end time (seconds):  3736.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 467
# ----------------------
# Waveform SNR:  81.99358195014126
# Injection location (seconds):  3743.9931640625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3743.986328125
# Window end time (seconds):  3744.95556640625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 468
# ----------------------
# Waveform SNR:  82.13517214098988
# Injection location (seconds):  3752.00830078125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3752.0
# Window end time (seconds):  3752.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 469
# ----------------------
# Waveform SNR:  79.6003110188003
# Injection location (seconds):  3759.993896484375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3759.98779296875
# Window end time (seconds):  3760.95703125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 470
# ----------------------
# Waveform SNR:  83.19087561779705
# Injection location (seconds):  3768.000244140625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3768.0
# Window end time (seconds):  3768.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 471
# ----------------------
# Waveform SNR:  81.85347033237214
# Injection location (seconds):  3776.006103515625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3776.0
# Window end time (seconds):  3776.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 472
# ----------------------
# Waveform SNR:  80.0657860645299
# Injection location (seconds):  3783.995849609375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3783.99169921875
# Window end time (seconds):  3784.9609375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 473
# ----------------------
# Waveform SNR:  80.97981835944418
# Injection location (seconds):  3791.998779296875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3791.99755859375
# Window end time (seconds):  3792.966796875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 474
# ----------------------
# Waveform SNR:  84.73799719777438
# Injection location (seconds):  3799.993408203125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3799.98681640625
# Window end time (seconds):  3800.9560546875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 475
# ----------------------
# Waveform SNR:  81.47313589464707
# Injection location (seconds):  3807.999755859375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3807.99951171875
# Window end time (seconds):  3808.96875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 476
# ----------------------
# Waveform SNR:  80.25824660504195
# Injection location (seconds):  3815.99462890625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3815.9892578125
# Window end time (seconds):  3816.95849609375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 477
# ----------------------
# Waveform SNR:  79.83003285717675
# Injection location (seconds):  3823.993408203125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3823.98681640625
# Window end time (seconds):  3824.9560546875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 478
# ----------------------
# Waveform SNR:  81.45535286845315
# Injection location (seconds):  3831.995361328125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3831.99072265625
# Window end time (seconds):  3832.9599609375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 479
# ----------------------
# Waveform SNR:  81.04832964180535
# Injection location (seconds):  3840.002685546875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3840.0
# Window end time (seconds):  3840.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 480
# ----------------------
# Waveform SNR:  81.67889248890556
# Injection location (seconds):  3847.998046875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3847.99609375
# Window end time (seconds):  3848.96533203125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 481
# ----------------------
# Waveform SNR:  81.59903771932152
# Injection location (seconds):  3855.997802734375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3855.99560546875
# Window end time (seconds):  3856.96484375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 482
# ----------------------
# Waveform SNR:  82.19874654004296
# Injection location (seconds):  3863.99365234375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3863.9873046875
# Window end time (seconds):  3864.95654296875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 483
# ----------------------
# Waveform SNR:  81.55324528788131
# Injection location (seconds):  3872.002685546875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3872.0
# Window end time (seconds):  3872.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 484
# ----------------------
# Waveform SNR:  81.31742356857131
# Injection location (seconds):  3880.00732421875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3880.0
# Window end time (seconds):  3880.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 485
# ----------------------
# Waveform SNR:  80.83197722380133
# Injection location (seconds):  3888.004638671875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3888.0
# Window end time (seconds):  3888.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 486
# ----------------------
# Waveform SNR:  81.14413305427921
# Injection location (seconds):  3896.003662109375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3896.0
# Window end time (seconds):  3896.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 487
# ----------------------
# Waveform SNR:  82.32292165517025
# Injection location (seconds):  3904.008056640625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3904.0
# Window end time (seconds):  3904.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 488
# ----------------------
# Waveform SNR:  82.34675168720631
# Injection location (seconds):  3912.00537109375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3912.0
# Window end time (seconds):  3912.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 489
# ----------------------
# Waveform SNR:  80.64164998392722
# Injection location (seconds):  3919.992919921875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3919.98583984375
# Window end time (seconds):  3920.955078125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 490
# ----------------------
# Waveform SNR:  80.8189960756991
# Injection location (seconds):  3927.99267578125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3927.9853515625
# Window end time (seconds):  3928.95458984375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 491
# ----------------------
# Waveform SNR:  82.54875207289169
# Injection location (seconds):  3935.99951171875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3935.9990234375
# Window end time (seconds):  3936.96826171875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 492
# ----------------------
# Waveform SNR:  81.27060418148065
# Injection location (seconds):  3943.999755859375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3943.99951171875
# Window end time (seconds):  3944.96875
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 493
# ----------------------
# Waveform SNR:  81.42688371620714
# Injection location (seconds):  3951.9990234375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3951.998046875
# Window end time (seconds):  3952.96728515625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 494
# ----------------------
# Waveform SNR:  81.4855341923412
# Injection location (seconds):  3959.99658203125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3959.9931640625
# Window end time (seconds):  3960.96240234375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 495
# ----------------------
# Waveform SNR:  81.5391808376364
# Injection location (seconds):  3968.006103515625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3968.0
# Window end time (seconds):  3968.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 496
# ----------------------
# Waveform SNR:  82.05210194598826
# Injection location (seconds):  3975.9970703125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3975.994140625
# Window end time (seconds):  3976.96337890625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 497
# ----------------------
# Waveform SNR:  81.02969074590939
# Injection location (seconds):  3983.996826171875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3983.99365234375
# Window end time (seconds):  3984.962890625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 498
# ----------------------
# Waveform SNR:  80.7512888102125
# Injection location (seconds):  3991.99267578125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  3991.9853515625
# Window end time (seconds):  3992.95458984375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 499
# ----------------------
# Waveform SNR:  80.42244116973225
# Injection location (seconds):  4000.003173828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4000.0
# Window end time (seconds):  4000.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 500
# ----------------------
# Waveform SNR:  83.51016437726219
# Injection location (seconds):  4008.00048828125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4008.0
# Window end time (seconds):  4008.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 501
# ----------------------
# Waveform SNR:  82.22778530537192
# Injection location (seconds):  4016.00634765625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4016.0
# Window end time (seconds):  4016.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 502
# ----------------------
# Waveform SNR:  81.09260938918094
# Injection location (seconds):  4024.001220703125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4024.0
# Window end time (seconds):  4024.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 503
# ----------------------
# Waveform SNR:  81.46028177017398
# Injection location (seconds):  4032.004638671875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4032.0
# Window end time (seconds):  4032.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 504
# ----------------------
# Waveform SNR:  80.62623680490512
# Injection location (seconds):  4040.005615234375
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4040.0
# Window end time (seconds):  4040.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 505
# ----------------------
# Waveform SNR:  81.03435693520171
# Injection location (seconds):  4047.9921875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4047.984375
# Window end time (seconds):  4048.95361328125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 506
# ----------------------
# Waveform SNR:  81.30864661573153
# Injection location (seconds):  4056.001220703125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4056.0
# Window end time (seconds):  4056.96923828125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 507
# ----------------------
# Waveform SNR:  79.9130760810869
# Injection location (seconds):  4063.999267578125
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4063.99853515625
# Window end time (seconds):  4064.9677734375
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 508
# ----------------------
# Waveform SNR:  80.55562700869504
# Injection location (seconds):  4071.996826171875
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4071.99365234375
# Window end time (seconds):  4072.962890625
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 509
# ----------------------
# Waveform SNR:  80.89787465389408
# Injection location (seconds):  4079.994384765625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4079.98876953125
# Window end time (seconds):  4080.9580078125
# Extracted  3970  data points
#
# ****************************************************************
#
# Window sample No. 510
# ----------------------
# Waveform SNR:  82.20974873699409
# Injection location (seconds):  4088.0087890625
#
# Waveform duration (seconds):  1.219970703125
#
# Window initial time (seconds):  4088.0
# Window end time (seconds):  4088.96923828125
# Extracted  3970  data points
#
# ****************************************************************

# %% [markdown]
# ### 4.4. Save log data

# %%
# ------> Create df_log dataframe
df_log = pd.DataFrame(log_data, columns=['Injection time [s]', 'jitter (seconds)', 'Waveform SNR', 'Waveform duration [s]'])

# ------> Export df_log dataframe to a csv file
df_log.to_csv(datasets_dir + '/log.dat', index=False)
